# %% [markdown]
# # Applying NLP for topic modelling in a real-life context
#
# In this project, we will bridge the gap between theory and practical application by developing automated topic modelling tools tailored to a specific industry context.
#
# Applying NLP for topic modelling is crucial for data analysis in business because it enables companies to identify and understand key themes and patterns within large volumes of text data. This efficiency allows businesses to extract essential insights and trends without manually sifting through extensive documents. Automated topic modelling helps businesses make informed decisions faster, which helps to improve productivity and gain a competitive edge. Additionally, it supports better information management by uncovering underlying topics in reports, emails, customer feedback, and market research, which enhances overall business intelligence and strategic planning.
# <br>
#
# ## **Business context**
#
# The PureGym Group, founded in 2008, has approximately 2 million members and 600 gyms across the world (particularly in the UK, Denmark, and Switzerland). As one of the world’s largest value fitness operators, PureGym appeals to a broad range of customers by offering high-quality, low-cost, and flexible fitness facilities. The company’s customer-centric proposition – affordable membership fees, no fixed-term contracts, and 24/7 access to high-quality gyms – differentiates it from more traditional gyms and elevates it as a market leader within this space.
#
# This focus on the customer is centred on wanting to understand what motivates members to join and what factors influence their behaviours once they have joined. Understanding how to leverage innovative technology to influence, improve, and simplify their experience allows PureGym to foster an open, welcoming, and diverse environment for its members while maintaining the value proposition that PureGym is built upon.
#
# With the shift in focus to value-for-money memberships across the gym industry, PureGym seeks to achieve its mission of ‘inspiring a healthier world by providing members with affordable access to the benefits being healthy can offer’.
#
# <br></br>
#
# ## **Objective**
#
# By the end of this topic project, we will have analysed PureGym's review data to uncover key drivers that provide actionable insights for enhancing customer experience.
#
# In the Notebook, you will:
#
# - Use two data sets containing customer reviews from Google and Trustpilot.
# - Perform basic level analysis by finding the frequently used words in both data sets.
# - Generate a wordcloud to visualise the most frequently used words in the reviews.
# - Apply BERTopic for topic modelling, keeping track of gym locations, to identify common topics and words in the negative reviews.
# - Identify the locations that have the most negative reviews.
# - Use the built-in visualisation functions in BERTopic to cluster and visually represent the topics and words in these reviews, thereby helping to identify specific themes from the reviews.
# - Conduct a comparison with Gensim’s LDA model to validate the topic modelling results.
# - Perform emotion analysis to identify the emotions associated with customer reviews.
# - Filter out angry reviews and apply BERTopic to discover prevalent topics and words being discussed these negative reviews.
# - Leverage the multi-purpose capability of the state-of-the-art Falcon-7b-instruct model, with the help of prompts, to identify top topics in each review.
# - Use a different prompt with the Falcon-7b-instruct model to further generate suggestions for improvements for PureGym, based on the top topics identified from the negative reviews.
# <br></br>
#
# By completing this project, you will be able to provide evidence that you can:
#
# - Investigate real-world data to find potential trends for deeper investigation.
# -Preprocess and refine textual data for visualisations.
# -Apply topic modelling using various techniques.
# -Apply emotion analysis using BERT.
# -Evaluate the outcomes of your investigation.
# -Communicate actionable insights.
# <br></br>
#
# ## **Project guidance**
#
# **Import packages and data:**
# 1. 1. Import the data set with the provided URL:
#   - Data set's Drive link: https://drive.google.com/drive/folders/1azch13dtGeAkbnEjqeoyl3nU9jheojU4
# 2. Import the data file **Google_12_months.xlsx** into a dataframe.
# 3. Import the data file **Trustpilot_12_months.xslx** into a dataframe.
# 4. Remove any rows with missing values in the Comment column (Google review) and Review Content column (Trustpilot).
#
#
# **Conducting initial data investigation:**
#
# 1. - Find the number of unique locations in the Google data set.
#
#   - Find the number of unique locations in the Trustpilot data set.
#
#   - Use Club's Name for the Google data set.
#
#   - Use Location Name for the Trustpilot data set.
# 2. Find the number of common locations between the Google data set and the Trustpilot data set.
# 3. Perform preprocessing of the data – change to lower case, remove stopwords using NLTK, and remove numbers.
# 4. Tokenise the data using word_tokenize from NLTK.
# 5. Find the frequency distribution of the words from each data set's reviews separately. You can use nltk.freqDist.
# 6. Plot a histogram/bar plot showing the top 10 words from each data set.
# 7. Use the wordcloud library on the cleaned data and plot the word cloud.
# 8. Create a new dataframe by filtering out the data to extract only the negative reviews from both data sets.
#
#   • For Google reviews, overall scores < 3 can be considered negative scores.
#
#   • For Trustpilot reviews, stars < 3 can be considered negative scores.
#
#   Repeat the frequency distribution and wordcloud steps on the filtered data consisting of only negative reviews.
#
#
# **Conducting initial topic modelling:**
#
# 1. With the data frame created in the previous step:
#
#   • Filter out the reviews that are from the locations common to both data sets.
#
#   • Merge the reviews to form a new list.
#
# 2. Preprocess this data set. Use BERTopic on this cleaned data set.
# 3. Output: List out the top topics along with their document frequencies.
# 4. For the top 2 topics, list out the top words.
# 5. Show an interactive visualisation of the topics to identify the cluster of topics and to understand the intertopic distance map.
# 6. Show a barchart of the topics, displaying the top 5 words in each topic.
# 7. Plot a heatmap, showcasing the similarity matrix.
# 8. For 10 clusters, provide a brief description in the Notebook of the topics they comprise of along with the general theme of the cluster, evidenced by the top words within each cluster's topics.
#
# **Performing further data investigation:**
#
# 1. List out the top 20 locations with the highest number of negative reviews. Do this separately for Google and Trustpilot's reviews, and comment on the result. Are the locations roughly similar in both data sets?
# 2. Merge the 2 data sets using Location Name and Club's Name.
#
#   Now, list out the following:
#
#   • Locations
#
#   • Number of Trustpilot reviews for this location
#
#   • Number of Google reviews for this location
#
#   • Total number of reviews for this location (sum of Google reviews and Trustpilot reviews)
#
#   Sort based on the total number of reviews.
# 3. For the top 30 locations, redo the word frequency and word cloud. Comment on the results, and highlight if the results are different from the first run.
# 4. For the top 30 locations, combine the reviews from Google and Trustpilot and run them through BERTopic.
#
#   Comment on the following:
#
#   • Are the results any different from the first run of BERTopic?
#
#   • If so, what has changed?
#
#   • Are there any additional insights compared to the first run?
#
# **Conducting emotion analysis:**
#
# 1. Import the BERT model bhadresh-savani/bert-base-uncased-emotion from Hugging Face, and set up a pipeline for text classification.
# 2. With the help of an example sentence, run the model and display the different emotion classifications that the model outputs.
# 3. Run this model on both data sets, and capture the top emotion for each review.
# 4. Use a bar plot to show the top emotion distribution for all negative reviews in both data sets.
# 5. Extract all the negative reviews (from both data sets) where anger is top emotion.
# 6. Run BERTopic on the output of the previous step.
# 7. Visualise the clusters from this run. Comment on whether it is any different from the previous runs, and whether it is possible to narrow down the primary issues that have led to an angry review.
#
# **Using a large language model (LLM) from Hugging Face:**
#
# 1. Load the following model: tiiuae/falcon-7b-instruct. Set the pipeline for text generation and a max length of 1,000 for each review.
# 2. Add the following prompt to every review, before passing it on to the model: **In the following customer review, pick out the main 3 topics. Return them in a numbered list format, with each one on a new line.**
#
#   Run the model.
#
#   Note: If the execution time is too high, you can use a subset of the bad reviews (instead of the full set) to run this model.
# 3. The output of the model will be the top 3 topics from each review. Append each of these topics from each review to create a comprehensive list.
# 4. Use this list as input to run BERTopic again.
# 5. Comment about the output of BERTopic. Highlight any changes, improvements, and if any further insights have been obtained.
# 6. Use the comprehensive list from Step 3.
#
#   Pass it to the model as the input, but pre-fix the following to the prompt: **For the following text topics obtained from negative customer reviews, can you give some actionable insights that would help this gym company?**
#
#   Run the Falcon-7b-Instruct model.
# 7. List the output, ideally in the form of suggestions, that the company can employ to address customer concerns.
#
# **Using Gensim:**
# 1. Perform the preprocessing required to run the LDA model from Gensim. Use the list of negative reviews (combined Google and Trustpilot reviews).
# 2. Using Gensim, perform LDA on the tokenised data. Specify the number of topics = 10.
# 3. Show the visualisations of the topics, displaying the distance maps and the bar chart listing out the most salient terms.
# 4. Comment on the output and whether it is similar to other techniques, or whether any extra insights were obtained.
#
# <br></br>

# %% [markdown]
# # Section: Importing Packages and Data
# ## 1. Importing data from Google Drive link

# %%
# Load the Course 3 data sets.
import os
import pandas as pd
# Install the gdown library if not installed
# !pip install gdown
import gdown

# %% [markdown]
# ## 2. Importing data in Excel file Google_12_months.xlsx

# %%
# Load the Course 3 Google data set.
# Use gdown to download the file from Google Drive
#url = 'https://docs.google.com/spreadsheets/d/13TeZTT6oqk3iPELBhFx9hComIfChKw4m/export?format=xlsx'
url = 'https://docs.google.com/spreadsheets/d/13TeZTT6oqk3iPELBhFx9hComIfChKw4m/export?format=xlsx'
output = 'Google_12_months.xlsx'
gdown.download(url, output, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
gdatadf = pd.read_excel(output, index_col=0, engine='openpyxl')
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/13TeZTT6oqk3iPELBhFx9hComIfChKw4m/export?format=xlsx
# To: /content/Google_12_months.xlsx
# 2.08MB [00:00, 10.5MB/s]

# %%
print(gdatadf.shape)
gdatadf.head()
# Out:
# (23250, 6)
#               SurveyID for external use (e.g. tech support)  \
# Customer Name
# **                                 ekkt2vyxtkwrrrfyzc5hz6rk
# **                                 e9b62vyxtkwrrrfyzc5hz6rk
# **                                 e2dkxvyxtkwrrrfyzc5hz6rk
# **                                 e3tfxvyxtkwrrrfyzc5hz6rk
# **                                 edkrxvyxtkwrrrfyzc5hz6rk
#
#                                      Club's Name Social Media Source  \
# Customer Name
# **                       Leeds City Centre North      Google Reviews
# **                        Cambridge Leisure Park      Google Reviews
# **                                London Holborn      Google Reviews
# **             Cheshunt Brookfield Shopping Park      Google Reviews
# **                            Bristol Union Gate      Google Reviews
#
#                     Creation Date  \
# Customer Name
# **            2024-05-09 23:49:18
# **            2024-05-09 22:48:39
# ...

# %% [markdown]
# ## 3. Importing data in Excel file Trustpilot_12_months.xlsx

# %%
# Load the Course 3 Trustpilot data set.
# Use gdown to download the file from Google Drive
url2 = 'https://docs.google.com/spreadsheets/d/1V6Pr6xWrHSHaothB61MJbR7mPFHwQ1u6/export?format=xlsx'
output2 = 'Trustpilot_12_months.xlsx'
gdown.download(url2, output2, quiet=False)

# Read the downloaded Excel file into a pandas DataFrame
tdatadf = pd.read_excel(output2, index_col=0, engine='openpyxl')
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1V6Pr6xWrHSHaothB61MJbR7mPFHwQ1u6/export?format=xlsx
# To: /content/Trustpilot_12_months.xlsx
# 2.83MB [00:00, 13.2MB/s]

# %%
print(tdatadf.shape)
tdatadf.head()
# Out:
# (16673, 14)
#                          Review Created (UTC)   Review Consumer User ID  \
# Review ID
# 663d40378de0a14c26c2f63c  2024-05-09 23:29:00  663d4036d5fa24c223106005
# 663d3c101ccfcc36fb28eb8c  2024-05-09 23:11:00  5f5e3434d53200fa6ac57238
# 663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 663d4fa1f25670a3339ccf6d  2024-05-09 22:35:00  663d4fa0d5fa24251d1068e7
# 663d3251d8367b7b3c4ace64  2024-05-09 22:30:00  60c20598384d84001a4250de
#
#                                            Review Title  \
# Review ID
# 663d40378de0a14c26c2f63c        A very good environment
# 663d3c101ccfcc36fb28eb8c  I love to be part of this gym
# 663d375859621080d08e6198                 Extremely busy
# 663d4fa1f25670a3339ccf6d                    Great vibes
# 663d3251d8367b7b3c4ace64      Everything it needs to be
#
#                                                              Review Content  \
# Review ID
# ...

# %%
gdatadf.reset_index()
# Out:
#       Customer Name SurveyID for external use (e.g. tech support)  \
# 0                **                      ekkt2vyxtkwrrrfyzc5hz6rk
# 1                **                      e9b62vyxtkwrrrfyzc5hz6rk
# 2                **                      e2dkxvyxtkwrrrfyzc5hz6rk
# 3                **                      e3tfxvyxtkwrrrfyzc5hz6rk
# 4                **                      edkrxvyxtkwrrrfyzc5hz6rk
# ...             ...                                           ...
# 23245            **                          e825yhvn9k6zn6mt9mb9
# 23246            **                          embs4hvn9k6zn6mt9mb9
# 23247            **                          edtc5kvn9k6zn6mt9mb9
# 23248            **                          e2p74kvn9k6zn6mt9mb9
# 23249            **                          eyk8ykvn9k6zn6mt9mb9
#
#                              Club's Name Social Media Source  \
# 0                Leeds City Centre North      Google Reviews
# ...

# %%
tdatadf.reset_index()
# Out:
#                       Review ID Review Created (UTC)  \
# 0      663d40378de0a14c26c2f63c  2024-05-09 23:29:00
# 1      663d3c101ccfcc36fb28eb8c  2024-05-09 23:11:00
# 2      663d375859621080d08e6198  2024-05-09 22:51:00
# 3      663d4fa1f25670a3339ccf6d  2024-05-09 22:35:00
# 4      663d3251d8367b7b3c4ace64  2024-05-09 22:30:00
# ...                         ...                  ...
# 16668  6463f601734f97e68fb3311b  2023-05-16 23:30:00
# 16669  6463f343746ca7dfea1e8cd4  2023-05-16 23:18:00
# 16670  6463f2c0734f97e68fb32f87  2023-05-16 23:16:00
# 16671  6463f271734f97e68fb32f62  2023-05-16 23:15:00
# 16672  6463f009734f97e68fb32e16  2023-05-16 23:05:00
#
#         Review Consumer User ID                             Review Title  \
# 0      663d4036d5fa24c223106005                  A very good environment
# 1      5f5e3434d53200fa6ac57238            I love to be part of this gym
# 2      57171ba90000ff000a18f905                           Extremely busy
# ...

# %% [markdown]
# ## 4. Removing any rows with missing values in the Comment column (Google review) and Review Content column (Trustpilot)

# %%
gdatadf.isnull().sum()
# Out:
# SurveyID for external use (e.g. tech support)       0
# Club's Name                                         0
# Social Media Source                                 0
# Creation Date                                       0
# Comment                                          9352
# Overall Score                                       0
# dtype: int64

# %% [markdown]
# About 9352 rows which have the Comment column with no value in Google data set.

# %%
googledatadf = gdatadf.dropna(subset=['Comment'])

# %%
googledatadf.isnull().sum()
# Out:
# SurveyID for external use (e.g. tech support)    0
# Club's Name                                      0
# Social Media Source                              0
# Creation Date                                    0
# Comment                                          0
# Overall Score                                    0
# dtype: int64

# %%
googledatadf.reset_index()
# Out:
#       Customer Name SurveyID for external use (e.g. tech support)  \
# 0                **                      e9b62vyxtkwrrrfyzc5hz6rk
# 1                **                      e2dkxvyxtkwrrrfyzc5hz6rk
# 2                **                      e3tfxvyxtkwrrrfyzc5hz6rk
# 3                **                      edkrxvyxtkwrrrfyzc5hz6rk
# 4                **                      ewbyf88stkwrrrfyzc5hz6rk
# ...             ...                                           ...
# 13893            **                          e48f5mvn9k6zn6mt9mb9
# 13894            **                          e825yhvn9k6zn6mt9mb9
# 13895            **                          embs4hvn9k6zn6mt9mb9
# 13896            **                          edtc5kvn9k6zn6mt9mb9
# 13897            **                          e2p74kvn9k6zn6mt9mb9
#
#                              Club's Name Social Media Source  \
# 0                 Cambridge Leisure Park      Google Reviews
# ...

# %% [markdown]
# Thus, the dataframe googledatadf contains all rows with the 'Comment' variable having no null value.

# %%
tdatadf.isnull().sum()
# Out:
# Review Created (UTC)            0
# Review Consumer User ID         0
# Review Title                    0
# Review Content                  0
# Review Stars                    0
# Source Of Review                0
# Review Language                 0
# Domain URL                      0
# Webshop Name                    0
# Business Unit ID                0
# Tags                        16673
# Company Reply Date (UTC)      509
# Location Name                5350
# Location ID                  5350
# dtype: int64

# %% [markdown]
# No row of the Truspilot data set has a no value in Review Content column. We also note Location Name column having 5350 rows with no values.

# %% [markdown]
# # Section: Conducting initial data investigation:
#
# ## 1a. Find the number of unique locations in the Google data set. Use Club's Name for Google data set.

# %%
googledatadf['Club\'s Name'].nunique()
# Out:
# 512

# %% [markdown]
# ## 1b. Find the number of unique locations in the Truspilot data set. Use Location Name for the Trustpilot data set.

# %%
tdatadf['Location Name'].nunique()
# Out:
# 376

# %% [markdown]
# ## 2. Finding the number of common locations between the Google data set and the Trustpilot data set.

# %%
cldf = googledatadf[googledatadf['Club\'s Name'].isin(tdatadf['Location Name'])]
cldf.reset_index()
# Out:
#       Customer Name SurveyID for external use (e.g. tech support)  \
# 0                **                      e9b62vyxtkwrrrfyzc5hz6rk
# 1                **                      e2dkxvyxtkwrrrfyzc5hz6rk
# 2                **                      e3tfxvyxtkwrrrfyzc5hz6rk
# 3                **                      edkrxvyxtkwrrrfyzc5hz6rk
# 4                **                      erx6f88stkwrrrfyzc5hz6rk
# ...             ...                                           ...
# 10610            **                          e48f5mvn9k6zn6mt9mb9
# 10611            **                          e825yhvn9k6zn6mt9mb9
# 10612            **                          embs4hvn9k6zn6mt9mb9
# 10613            **                          edtc5kvn9k6zn6mt9mb9
# 10614            **                          e2p74kvn9k6zn6mt9mb9
#
#                              Club's Name Social Media Source  \
# 0                 Cambridge Leisure Park      Google Reviews
# ...

# %%
print(cldf['Club\'s Name'].nunique())
# Out:
# 310

# %%
rcldf = tdatadf[tdatadf['Location Name'].isin(googledatadf['Club\'s Name'])]
rcldf.reset_index()
# Out:
#                      Review ID Review Created (UTC)   Review Consumer User ID  \
# 0     663d3c101ccfcc36fb28eb8c  2024-05-09 23:11:00  5f5e3434d53200fa6ac57238
# 1     663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 2     663d4fa1f25670a3339ccf6d  2024-05-09 22:35:00  663d4fa0d5fa24251d1068e7
# 3     663d298d98d74d5ae28f28aa  2024-05-09 21:52:00  5e4db26368c4b9863fcd4261
# 4     663d24193e964ae4bfe7d97b  2024-05-09 21:29:00  59bcd29c0000ff000ac9dc29
# ...                        ...                  ...                       ...
# 9153  646444bf468658bd23d37014  2023-05-17 05:06:00  6279b97cad44e300114d6607
# 9154  6464066f734f97e68fb336dd  2023-05-17 00:40:00  57cb0c470000ff000a40c28d
# 9155  6463f601734f97e68fb3311b  2023-05-16 23:30:00  5e7a140edffcf7e4c390cb4b
# 9156  6463f343746ca7dfea1e8cd4  2023-05-16 23:18:00  538dce7d00006400017729a2
# 9157  6463f009734f97e68fb32e16  2023-05-16 23:05:00  6463f00855c27c0013aaf829
#
# ...

# %%
print(rcldf['Location Name'].nunique())
# Out:
# 310

# %% [markdown]
# Thus, after checking in both googledatadf and tdatadf dataframes, we can confirm 310 unique locations that are common in the two dataframes.

# %% [markdown]
# ## 3. Perform preprocessing of the data – change to lower case, remove stopwords using NLTK, and remove numbers.
#
# We preprocess data as performed in Demonstration 3.3.3 (LDA):

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string

# %%
gdocuments = googledatadf['Comment'].to_list()
tdocuments = tdatadf['Review Content'].to_list()

# %%
gdocuments
# Out:
# ['Too many students from two local colleges go her leave rubbish in changing rooms and sit there like there in a canteen. Been going here for 5 years will cancel my membership and go to gym group. This gym is disgusting students hanging around machines and messing around like there at school. Too over crowded.( And their ceo supports the genocide of civilians by Israel). Disgusting people!!',
#  'Best range of equipment, cheaper than regular gyms. very professional and friendly staff that makes your gym your second home',
#  'Good gym when it’s not busy, tend to get too busy in the late afternoon and you can hardly get on a machine but other than that it has free parking and it’s in a good location.',
# ...

# %%
tdocuments
# Out:
# ['A very good environment',
#  'I love to be part of this gym. Superb value for money. Any time, any day. Love the app too, well organised building equipment, studio area, cycling area and more important feel safe.',
#  'Extremely busy, no fresh air.',
#  'Great vibes, fantastic gym',
#  'Clean, well managed, classes are good.',
#  'Good budget gym. Open 24/7. Young, keen and friendly staff. Nearby free parking. Free classes.',
#  'It was nice, lowk spacious. I went there for the first time and it was pretty chill. I don’t feel compelled to buy the 24 aces tho, save ur money and go earlier',
#  'Great gym felt very comfortable enjoyed my sessions',
#  "want to know why the code won't let me in. It will register me on the 7th day of age and it will tell me that I am not registered",
#  'Fun, worth the work out.',
# ...

# %% [markdown]
# ## Tokenisation using word_tokenize of NLTK

# %%
def preprocess_text(text):

    num_freetxt = ''.join(word for word in text if not word.isdigit())
    # Tokenise the text.
    tokens = word_tokenize(num_freetxt.lower())

    numfree_tokens = [token for token in tokens if not token.isdigit()]

    # Remove punctuation.
    punc_free_tokens = [token for token in numfree_tokens if token not in string.punctuation]
    # Remove stopwords.
    filtered_tokens = [token for token in punc_free_tokens if token not in stopwords.words('english')]

    # Lemmatise the tokens.
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    # Join the tokens back into a string.
    processed_text = ' '.join(lemmatized_tokens  )

    return processed_text

# %%
gdocsdf = pd.DataFrame(gdocuments, columns=['Comment'])
tdocsdf = pd.DataFrame(tdocuments, columns=['Review Content'])

# %%
gdocsdf.head()
# Out:
#                                              Comment
# 0  Too many students from two local colleges go h...
# 1  Best range of equipment, cheaper than regular ...
# 2  Good gym when it’s not busy, tend to get too b...
# 3  (current member)\n\nGym is quite dirty, more o...
# 4  Kom og betalte for en prøvetime i centret. Fik...

# %%
tdocsdf.head()
# Out:
#                                       Review Content
# 0                            A very good environment
# 1  I love to be part of this gym. Superb value fo...
# 2                      Extremely busy, no fresh air.
# 3                         Great vibes, fantastic gym
# 4             Clean, well managed, classes are good.

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
googletokens = gdocsdf['Comment'].apply(preprocess_text)
trustpilottokens = tdocsdf['Review Content'].apply(preprocess_text)
# Make a dataframe to add a column of 'cleantext' containing googletokens
gdocsdf['CleanText'] = googletokens
tdocsdf['CleanText'] = trustpilottokens
#gdocsdf['CleanText'] = gdocsdf['Comment'].apply(preprocess_text)
#tdocsdf['CleanText'] = tdocsdf['Review Content'].apply(preprocess_text)

# %%
gdocsdf.head()
# Out:
#                                              Comment  \
# 0  Too many students from two local colleges go h...
# 1  Best range of equipment, cheaper than regular ...
# 2  Good gym when it’s not busy, tend to get too b...
# 3  (current member)\n\nGym is quite dirty, more o...
# 4  Kom og betalte for en prøvetime i centret. Fik...
#
#                                            CleanText
# 0  many student two local college go leave rubbis...
# 1  best range equipment cheaper regular gym profe...
# 2  good gym ’ busy tend get busy late afternoon h...
# 3  current member gym quite dirty often 's soap b...
# 4  kom og betalte en prøvetime centret fik blot e...

# %%
tdocsdf.head()
# Out:
#                                       Review Content  \
# 0                            A very good environment
# 1  I love to be part of this gym. Superb value fo...
# 2                      Extremely busy, no fresh air.
# 3                         Great vibes, fantastic gym
# 4             Clean, well managed, classes are good.
#
#                                            CleanText
# 0                                   good environment
# 1  love part gym superb value money time day love...
# 2                           extremely busy fresh air
# 3                           great vibe fantastic gym
# 4                      clean well managed class good

# %% [markdown]
# ## 6. Find the frequency distribution of the words from each data set's reviews separately, using nltk.freqDist.
#
# ### 6a. Google dataset

# %%
from nltk import FreqDist
from nltk.tokenize import RegexpTokenizer, word_tokenize
gcldocs = gdocsdf['CleanText'].to_list()
# Tokenize the text into individual words
tokenizer = nltk.RegexpTokenizer(r"\w+")
gtokens = tokenizer.tokenize(str(gcldocs))

gtokens = [token for token in gtokens if len(token) > 1]
# Now gcldocs contains all comments tokenized by NLTK word_tokenizer
# create a FreqDist object
gfreq_dist = FreqDist(gtokens)

# total N
print('N:',gfreq_dist.N())

# Most frequent words
print("Most frequent words:", gfreq_dist.most_common(5))
# Out:
# N: 269861
# Most frequent words: [('gym', 10644), ('equipment', 3781), ('class', 3683), ('great', 3570), ('good', 3467)]

# %%
# Plot the 10 most frequent words
gfreq_dist.plot(10)
print()

# %%
# element freq
print('Word frequencies:')
for item in gfreq_dist.elements():
  print('frequency:', gfreq_dist.freq(item))
print()
# Out:
# Streaming output truncated to the last 5000 lines.
# frequency: 7.411222814708313e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 7.411222814708313e-06
# frequency: 7.411222814708313e-06
# frequency: 3.7056114073541565e-06
# frequency: 1.1116834222062469e-05
# frequency: 1.1116834222062469e-05
# frequency: 1.1116834222062469e-05
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 7.411222814708313e-06
# frequency: 7.411222814708313e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 3.7056114073541565e-06
# frequency: 7.411222814708313e-06
# frequency: 7.411222814708313e-06
# frequency: 3.7056114073541565e-06
# frequency: 7.411222814708313e-06
# frequency: 7.411222814708313e-06
# ...

# %% [markdown]
# ### 6b. Trustpilot data set

# %%
tcldocs = tdocsdf['CleanText'].to_list()
# Now gcldocs contains all comments tokenized by NLTK word_tokenizer
# create a FreqDist object
tfreq_dist = FreqDist(tcldocs)
# Tokenize the text into individual words
tokenizer = nltk.RegexpTokenizer(r"\w+")
ttokens = tokenizer.tokenize(str(tcldocs))

ttokens = [token for token in ttokens if len(token) > 1]
# total N
print('N:', tfreq_dist.N())

# Most frequent words
print("Most frequent words:", tfreq_dist.most_common(5))
# Out:
# N: 16673
# Most frequent words: [('easy join', 60), ('quick easy', 26), ('good gym', 20), ('easy sign', 18), ('easy', 15)]

# %%
# Plot the 10 most frequent words
tfreq_dist.plot(10)
print()

# %%
# element freq
print('Word frequencies:')
for item in tfreq_dist.elements():
  print('frequency:', tfreq_dist.freq(item))
print()
# Out:
# Streaming output truncated to the last 5000 lines.
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# frequency: 5.997720866070893e-05
# ...

# %% [markdown]
# ### 6.Plot a histogram/bar plot showing the top 10 words from each data set
#
# ### 6a. Google Data Set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## Creating FreqDist for whole BoW, keeping the 20 most common tokens
all_fdist = FreqDist(gtokens).most_common(10)

## Conversion to Pandas series via Python Dictionary for easier plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,10))

## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
# Set a color palette
color_palette = sns.color_palette("husl", len(all_fdist))

# Create the barplot with the specified color palette
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, hue=all_fdist.index, ax=ax, palette=color_palette, legend=False)
plt.xticks(rotation=30, horizontalalignment='right')

# Remove the default legend
#ax.legend().remove()
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Words in Google Reviews')

# Display the plot
plt.show()

# %% [markdown]
# We note above the single letter toke 's' in the bar graph. So, we'll remove single-letter tokens which do not make sense for this analysis.

# %% [markdown]
# ### 6b. Trustpilot data set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## Creating FreqDist for whole BoW, keeping the 20 most common tokens
all_fdist = FreqDist(ttokens).most_common(10)

## Conversion to Pandas series via Python Dictionary for easier plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,10))

## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
# Set a color palette
color_palette = sns.color_palette("husl", len(all_fdist))

# Create the barplot with the specified color palette
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, hue=all_fdist.index, ax=ax, palette=color_palette, legend=False)
plt.xticks(rotation=30, fontsize=10, horizontalalignment='right')

# Remove the default legend
#ax.legend().remove()
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Words in Trustpilot Reviews')

# Display the plot
plt.show()

# %% [markdown]
# ### Removing single letter tokens

# %% [markdown]
# ##7. Use the wordcloud library on the cleaned data and plot the word cloud
#
# ### 7a. Google tokens

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''
stopwords = set(STOPWORDS)

comment_words += " ".join(gtokens)+" "
wordcloud = WordCloud(width = 1000, height = 1000,
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# ### 7b. Trustpilot tokens

# %%
comment_words = ''
stopwords = set(STOPWORDS)

comment_words += " ".join(ttokens)+" "
wordcloud = WordCloud(width = 1000, height = 1000,
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# #8. Create a new dataframe by filtering out the data to extract only the negative reviews from both data sets.
#
# ##8a. For Google reviews, overall scores < 3 can be considered negative scores.

# %%
gNRdf = gdatadf[gdatadf['Overall Score'] < 3]
print(gNRdf.shape)
gNRdf.head()
# Out:
# (3218, 6)
#               SurveyID for external use (e.g. tech support)  \
# Customer Name
# **                                 e9b62vyxtkwrrrfyzc5hz6rk
# **                                 edkrxvyxtkwrrrfyzc5hz6rk
# **                                 ewbyf88stkwrrrfyzc5hz6rk
# **                                 erx6f88stkwrrrfyzc5hz6rk
# **                                 em5fxz3stkwrrrfyzc5hz6rk
#
#                                 Club's Name Social Media Source  \
# Customer Name
# **                   Cambridge Leisure Park      Google Reviews
# **                       Bristol Union Gate      Google Reviews
# **             209 - Slagelse, Jernbanegade      Google Reviews
# **                               New Barnet      Google Reviews
# **                 Manchester Cheetham Hill      Google Reviews
#
#                     Creation Date  \
# Customer Name
# **            2024-05-09 22:48:39
# **            2024-05-09 21:48:00
# **            2024-05-09 21:36:17
# ...

# %% [markdown]
# ## 8b. For Trustpilot 'Reviews Stars' < 3 can be considered negative scores.

# %%
tNRdf = tdatadf[tdatadf['Review Stars'] < 3]
print(tNRdf.shape)
tNRdf.head()
# Out:
# (3543, 14)
#                          Review Created (UTC)   Review Consumer User ID  \
# Review ID
# 663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 663cf54657cc0d5b9e4c3cf6  2024-05-09 18:09:00  663cf54563436600872ebfaf
# 663cb2bb3dd3bfa5d9aa722d  2024-05-09 13:25:00  663cb2bac225531f31f22a41
# 663cb0d7d2ae954c99ee3bb1  2024-05-09 13:17:00  663cb0d6cb6e8d68d6aacb9c
# 663ca6eef65e849c2d5d78d9  2024-05-09 12:35:00  601e9e42862682001b88eb67
#
#                                                     Review Title  \
# Review ID
# 663d375859621080d08e6198                          Extremely busy
# 663cf54657cc0d5b9e4c3cf6      The men’s changing rooms smell bad
# 663cb2bb3dd3bfa5d9aa722d  All I wanted to do was set up another…
# 663cb0d7d2ae954c99ee3bb1  What ever you do don’t downgrade your…
# 663ca6eef65e849c2d5d78d9                              Awful Gyms
#
#                                                              Review Content  \
# Review ID
# ...

# %% [markdown]
# ## 8c. Repeat the frequency distribution and wordcloud steps on the filtered data consisting of only negative reviews.

# %%
gNRdf.isnull().sum()
gNRdf = gNRdf.dropna(subset=['Comment'])
#gNRdf.isnull().sum()
#gNRdf.reset_index()

# %%
gNRdf.isnull().sum()
# Out:
# SurveyID for external use (e.g. tech support)    0
# Club's Name                                      0
# Social Media Source                              0
# Creation Date                                    0
# Comment                                          0
# Overall Score                                    0
# dtype: int64

# %%
gNRdf.reset_index()
# Out:
#      Customer Name SurveyID for external use (e.g. tech support)  \
# 0               **                      e9b62vyxtkwrrrfyzc5hz6rk
# 1               **                      edkrxvyxtkwrrrfyzc5hz6rk
# 2               **                      ewbyf88stkwrrrfyzc5hz6rk
# 3               **                      erx6f88stkwrrrfyzc5hz6rk
# 4               **                      em5fxz3stkwrrrfyzc5hz6rk
# ...            ...                                           ...
# 2780            **                          emm2t9tn9k6zn6mt9mb9
# 2781            **                          e3nr79tn9k6zn6mt9mb9
# 2782            **                          enkwn9tn9k6zn6mt9mb9
# 2783            **                          ebwbsbvn9k6zn6mt9mb9
# 2784            **                          e5hbbnvn9k6zn6mt9mb9
#
#                        Club's Name Social Media Source       Creation Date  \
# 0           Cambridge Leisure Park      Google Reviews 2024-05-09 22:48:39
# ...

# %%
tNRdf.isnull().sum()
# Out:
# Review Created (UTC)           0
# Review Consumer User ID        0
# Review Title                   0
# Review Content                 0
# Review Stars                   0
# Source Of Review               0
# Review Language                0
# Domain URL                     0
# Webshop Name                   0
# Business Unit ID               0
# Tags                        3543
# Company Reply Date (UTC)     129
# Location Name               1292
# Location ID                 1292
# dtype: int64

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string

# %%
gNRdocuments = gNRdf['Comment'].to_list()
tNRdocuments = tNRdf['Review Content'].to_list()

# %%
def preprocess_text(text):

    num_freetxt = ''.join(word for word in text if not word.isdigit())
    # Tokenise the text.
    tokens = word_tokenize(num_freetxt.lower())

    numfree_tokens = [token for token in tokens if not token.isdigit()]

    # Remove punctuation.
    punc_free_tokens = [token for token in numfree_tokens if token not in string.punctuation]
    # Remove stopwords.
    filtered_tokens = [token for token in punc_free_tokens if token not in stopwords.words('english')]

    filtered_tokens = [token for token in filtered_tokens if len(token) > 1]

    # Lemmatise the tokens.
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    # Join the tokens back into a string.
    processed_text = ' '.join(lemmatized_tokens  )

    return processed_text

# %%
gNRdocsdf = pd.DataFrame(gNRdocuments, columns=['Comment'])
tNRdocsdf = pd.DataFrame(tNRdocuments, columns=['Review Content'])

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
gNRtokens = gNRdocsdf['Comment'].apply(preprocess_text)
tNRtokens = tNRdocsdf['Review Content'].apply(preprocess_text)
# Make a dataframe to add a column of 'cleantext' containing googletokens
gNRdocsdf['CleanText'] = gNRtokens
tNRdocsdf['CleanText'] = tNRtokens

# %%
gNRdocsdf.head()
# Out:
#                                              Comment  \
# 0  Too many students from two local colleges go h...
# 1  (current member)\n\nGym is quite dirty, more o...
# 2  Kom og betalte for en prøvetime i centret. Fik...
# 3  This gym is way too hot to even workout in. Th...
# 4  No access for wc 😢.  Empty and no assistance t...
#
#                                            CleanText
# 0  many student two local college go leave rubbis...
# 1  current member gym quite dirty often 's soap b...
# 2  kom og betalte en prøvetime centret fik blot e...
# 3  gym way hot even workout window open ac barely...
# 4  access wc empty assistance gain access fault f...

# %%
tNRdocsdf.head()
# Out:
#                                       Review Content  \
# 0                      Extremely busy, no fresh air.
# 1  The men’s changing rooms smell bad. They need ...
# 2  All I wanted to do was set up another debit ca...
# 3  What ever you do don’t downgrade your membersh...
# 4  Poor parking, not enough kit, unhelpful traine...
#
#                                            CleanText
# 0                           extremely busy fresh air
# 1  men changing room smell bad need deep clean so...
# 2  wanted set another debit card direct debit opt...
# 3  ever downgrade membership core plus… cancel me...
# 4  poor parking enough kit unhelpful trainers/ st...

# %% [markdown]
# ### Frequency Distribution for Negative Reviews
#
# ### Google Data Set

# %%
from nltk import FreqDist
from nltk.tokenize import RegexpTokenizer, word_tokenize
gNRdocs = gNRdocsdf['CleanText'].to_list()
# Tokenize the text into individual words
tokenizer = nltk.RegexpTokenizer(r"\w+")
gNRtokens = tokenizer.tokenize(str(gNRdocs))
gNRtokens = [token for token in gNRtokens if len(token) > 1]
# Now gcldocs contains all comments tokenized by NLTK word_tokenizer
# create a FreqDist object
gfreq_dist = FreqDist(gNRtokens)

# total N
print('N:',gfreq_dist.N())

# Most frequent words
print("Most frequent words:", gfreq_dist.most_common(10))

# Plot the 10 most frequent words
gfreq_dist.plot(10)
print()
# Out:
# N: 93867
# Most frequent words: [('gym', 3316), ('equipment', 943), ('machine', 828), ('time', 771), ('staff', 724), ('people', 623), ('one', 606), ('get', 536), ('like', 473), ('member', 460)]

# %%
from nltk import FreqDist
from nltk.tokenize import RegexpTokenizer, word_tokenize

tNRdocs = tNRdocsdf['CleanText'].to_list()
# Tokenize the text into individual words
tokenizer = nltk.RegexpTokenizer(r"\w+")
tNRtokens = tokenizer.tokenize(str(tNRdocs))
tNRtokens = [token for token in tNRtokens if len(token) > 1]
# Now gcldocs contains all comments tokenized by NLTK word_tokenizer
# create a FreqDist object
gfreq_dist = FreqDist(tNRtokens)

# total N
print('N:',gfreq_dist.N())

# Most frequent words
print("Most frequent words:", gfreq_dist.most_common(10))

# Plot the 10 most frequent words
gfreq_dist.plot(10)
print()
# Out:
# N: 98896
# Most frequent words: [('gym', 3703), ('time', 799), ('equipment', 763), ('membership', 754), ('get', 740), ('machine', 719), ('one', 710), ('member', 683), ('staff', 622), ('class', 610)]

# %% [markdown]
# ### Bar chart for Google (Negative Reviews) first 10 most frequent words

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Creating FreqDist for whole BoW, keeping the 20 most common tokens
all_fdist = FreqDist(gNRtokens).most_common(10)

## Conversion to Pandas series via Python Dictionary for easier plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,10))

## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
# Set a color palette
color_palette = sns.color_palette("husl", len(all_fdist))

# Create the barplot with the specified color palette
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, hue=all_fdist.index, ax=ax, palette=color_palette, legend=False)
plt.xticks(rotation=30, horizontalalignment='right')

# Remove the default legend
#ax.legend().remove()
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Words in Negative Reviews of Google Data Set')

# Display the plot
plt.show()

# %% [markdown]
# ### Bar chart for Trustpilot (Negative Reviews) first 10 most frequent words

# %%
## Creating FreqDist for whole BoW, keeping the 20 most common tokens
all_fdist = FreqDist(tNRtokens).most_common(10)

## Conversion to Pandas series via Python Dictionary for easier plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,10))

## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
# Set a color palette
color_palette = sns.color_palette("husl", len(all_fdist))

# Create the barplot with the specified color palette
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, hue=all_fdist.index, ax=ax, palette=color_palette, legend=False)
plt.xticks(rotation=30, horizontalalignment='right')

# Remove the default legend
#ax.legend().remove()
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Words in Negative Reviews of Trustpilot Data Set')

# Display the plot
plt.show()

# %% [markdown]
# ### Wordcloud for Google Data Set (Negative Reviews)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''
stopwords = set(STOPWORDS)

comment_words += " ".join(gNRtokens)+" "
wordcloud = WordCloud(width = 1000, height = 1000,
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# ### Wordcloud for Trustpilot Data Set (Negative Reviews)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''
stopwords = set(STOPWORDS)

comment_words += " ".join(tNRtokens)+" "
wordcloud = WordCloud(width = 1000, height = 1000,
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# # Section: Conduct Initial Topic Modelling
# ## 1. With the data frame created in the previous step:
#
# ## 1a. Filter out the reviews that are from the locations common to both data sets.

# %%
gNRdf
# Out:
#               SurveyID for external use (e.g. tech support)  \
# Customer Name
# **                                 e9b62vyxtkwrrrfyzc5hz6rk
# **                                 edkrxvyxtkwrrrfyzc5hz6rk
# **                                 ewbyf88stkwrrrfyzc5hz6rk
# **                                 erx6f88stkwrrrfyzc5hz6rk
# **                                 em5fxz3stkwrrrfyzc5hz6rk
# ...                                                     ...
# **                                     emm2t9tn9k6zn6mt9mb9
# **                                     e3nr79tn9k6zn6mt9mb9
# **                                     enkwn9tn9k6zn6mt9mb9
# **                                     ebwbsbvn9k6zn6mt9mb9
# **                                     e5hbbnvn9k6zn6mt9mb9
#
#                                 Club's Name Social Media Source  \
# Customer Name
# **                   Cambridge Leisure Park      Google Reviews
# **                       Bristol Union Gate      Google Reviews
# ...

# %%
tNRdf
# Out:
#                          Review Created (UTC)   Review Consumer User ID  \
# Review ID
# 663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 663cf54657cc0d5b9e4c3cf6  2024-05-09 18:09:00  663cf54563436600872ebfaf
# 663cb2bb3dd3bfa5d9aa722d  2024-05-09 13:25:00  663cb2bac225531f31f22a41
# 663cb0d7d2ae954c99ee3bb1  2024-05-09 13:17:00  663cb0d6cb6e8d68d6aacb9c
# 663ca6eef65e849c2d5d78d9  2024-05-09 12:35:00  601e9e42862682001b88eb67
# ...                                       ...                       ...
# 64650b23746ca7dfea1f2295  2023-05-17 19:13:00  637f6cfc06d9ed0012704ab7
# 64650222e9b78858b84cd8ea  2023-05-17 18:34:00  6465021a98dbf4001253f23f
# 6464f7df088d79de92813104  2023-05-17 17:50:00  6464f7bd8fef9f001256c5d2
# 6464e761c73e7c45f251dc0e  2023-05-17 16:40:00  60522cf2b9cf59001a351091
# 6464c9791c8f4e0876e86f30  2023-05-17 14:32:00  5d474c3817d44eefb5c373cf
#
#                                                                Review Title  \
# Review ID
# ...

# %%
comloc_gNRdf = gNRdf[gNRdf['Club\'s Name'].isin(tNRdf['Location Name'])]
comloc_gNRdf.reset_index()
# Out:
#      Customer Name SurveyID for external use (e.g. tech support)  \
# 0               **                      e9b62vyxtkwrrrfyzc5hz6rk
# 1               **                      edkrxvyxtkwrrrfyzc5hz6rk
# 2               **                      erx6f88stkwrrrfyzc5hz6rk
# 3               **                      em5fxz3stkwrrrfyzc5hz6rk
# 4               **                      etbwctzttkwrrrfyzc5hz6rk
# ...            ...                                           ...
# 2042            **                          emm2t9tn9k6zn6mt9mb9
# 2043            **                          e3nr79tn9k6zn6mt9mb9
# 2044            **                          enkwn9tn9k6zn6mt9mb9
# 2045            **                          ebwbsbvn9k6zn6mt9mb9
# 2046            **                          e5hbbnvn9k6zn6mt9mb9
#
#                    Club's Name Social Media Source       Creation Date  \
# 0       Cambridge Leisure Park      Google Reviews 2024-05-09 22:48:39
# ...

# %%
comloc_tNRdf = tNRdf[tNRdf['Location Name'].isin(gNRdf['Club\'s Name'])]
comloc_tNRdf.reset_index()
# Out:
#                      Review ID Review Created (UTC)   Review Consumer User ID  \
# 0     663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 1     663cf54657cc0d5b9e4c3cf6  2024-05-09 18:09:00  663cf54563436600872ebfaf
# 2     663c78406be59f12dd1158d3  2024-05-09 09:16:00  5f4f77e550ac801923c3f33d
# 3     663c67278db0990f3063f147  2024-05-09 08:03:00  62cfefd71dd4400013090c74
# 4     663ba55fb7ecf6fa3ca37596  2024-05-08 18:16:00  60521c084d20a300198a5878
# ...                        ...                  ...                       ...
# 1836  64651947746ca7dfea1f2e23  2023-05-17 20:13:00  64651946ef90f40012396fc2
# 1837  64650b23746ca7dfea1f2295  2023-05-17 19:13:00  637f6cfc06d9ed0012704ab7
# 1838  6464f7df088d79de92813104  2023-05-17 17:50:00  6464f7bd8fef9f001256c5d2
# 1839  6464e761c73e7c45f251dc0e  2023-05-17 16:40:00  60522cf2b9cf59001a351091
# 1840  6464c9791c8f4e0876e86f30  2023-05-17 14:32:00  5d474c3817d44eefb5c373cf
#
# ...

# %%
comloc_gNRdf['Club\'s Name'].nunique()
# Out:
# 290

# %%
comloc_tNRdf['Location Name'].nunique()
# Out:
# 290

# %%
Reviews_gNRdf = pd.DataFrame(comloc_gNRdf['Comment'])
Reviews_gNRdf.reset_index()
# Out:
#      Customer Name                                            Comment
# 0               **  Too many students from two local colleges go h...
# 1               **  (current member)\n\nGym is quite dirty, more o...
# 2               **  This gym is way too hot to even workout in. Th...
# 3               **  No access for wc 😢.  Empty and no assistance t...
# 4               **  After being at this gym for over a year I'm fi...
# ...            ...                                                ...
# 2042            **  Equipment 7/10\n\nThey're pretty good, over th...
# 2043            **  "Alright for the price. Some members are a bit...
# 2044            **  Disorganised, cramped, and untidy. The old fre...
# 2045            **  music always too loud, especially when cycling...
# 2046            **  I used to love this gym, having been a member ...
#
# [2047 rows x 2 columns]

# %%
Reviews_tNRdf = pd.DataFrame(comloc_tNRdf['Review Content'])
Reviews_tNRdf.reset_index()
# Out:
#                      Review ID  \
# 0     663d375859621080d08e6198
# 1     663cf54657cc0d5b9e4c3cf6
# 2     663c78406be59f12dd1158d3
# 3     663c67278db0990f3063f147
# 4     663ba55fb7ecf6fa3ca37596
# ...                        ...
# 1836  64651947746ca7dfea1f2e23
# 1837  64650b23746ca7dfea1f2295
# 1838  6464f7df088d79de92813104
# 1839  6464e761c73e7c45f251dc0e
# 1840  6464c9791c8f4e0876e86f30
#
#                                          Review Content
# 0                         Extremely busy, no fresh air.
# 1     The men’s changing rooms smell bad. They need ...
# 2     No one was cleaning the equipment after use. C...
# 3     Not the best experience at 7am on a week day. ...
# 4     Staff have their hands tied but surely head of...
# ...                                                 ...
# 1836  There are lot of things to improve  There shou...
# 1837  Not enough weight plates for benches, spent ha...
# 1838  I've been a member of this gym for about  2 ye...
# ...

# %% [markdown]
# ## 1b. Merge the reviews to form a new list.

# %%
Rev_gNRList = Reviews_gNRdf['Comment'].to_list()
Rev_tNRList = Reviews_tNRdf['Review Content'].to_list()
MergedRev_gtNRList = Rev_gNRList + Rev_tNRList
MergedRev_gtNRdf = pd.DataFrame(MergedRev_gtNRList, columns=['Reviews'])

# %%
print(MergedRev_gtNRdf.shape)
MergedRev_gtNRdf.head()
# Out:
# (3888, 1)
#                                              Reviews
# 0  Too many students from two local colleges go h...
# 1  (current member)\n\nGym is quite dirty, more o...
# 2  This gym is way too hot to even workout in. Th...
# 3  No access for wc 😢.  Empty and no assistance t...
# 4  After being at this gym for over a year I'm fi...

# %% [markdown]
# ##2. Preprocess this data set. Use BERTopic on this cleaned data set.
#
# #### We'll adapt Russell's code for this part of our project.

# %%
# !pip install -U plotly==5.19.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 77.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')

from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from nltk.tokenize import RegexpTokenizer

import seaborn as sns
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### A Helper Function by Dr Russell

# %%
def word_cloud_display(df, key):
  top_number_of_results = 100
  all_reviews = df[key].str.lower().str.cat(sep=' ')
  all_text = re.sub('[^A-Za-z]+', ' ', all_reviews)

  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(all_text)
  filtered_all_reviews = [w for w in word_tokens if not w in stop_words]
  filtered_all_reviews = []
  for w in word_tokens:
      if w not in stop_words:
          filtered_all_reviews.append(w)

  all_reviews_no_short_words = [word for word in filtered_all_reviews if len(word) > 2]
  all_reviews_no_numbers = [word for word in all_reviews_no_short_words if not word.isnumeric()]
  word_distribution = nltk.FreqDist(all_reviews_no_numbers)
  reviews_word_frequency_distribution_df = pd.DataFrame(word_distribution.most_common(top_number_of_results),
                    columns=['Word', 'Frequency'])

  plt.figure(figsize=(10,10))
  sns.set_style("whitegrid")
  ax = sns.barplot(x="Word",y="Frequency", data=reviews_word_frequency_distribution_df.head(7))

  plt.figure(figsize = (100,100))
  wc = WordCloud(background_color = 'black', max_words = 1000,  max_font_size = 50)
  wc.generate(' '.join(all_reviews_no_numbers))
  plt.imshow(wc)
  plt.axis('off')

# %% [markdown]
# ## Topic Modelling using BERTopic

# %%
from transformers import pipeline

# %% [markdown]
# https://maartengr.github.io/BERTopic/index.html

# %%
# !pip install bertopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 40.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.3 MB/s eta 0:00:00
# ...

# %%
from bertopic import BERTopic

# %% [markdown]
# Let's clean our data by removing nulls and stopwords.

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
all_bad_reviews_list_clean = []
for review in MergedRev_gtNRList:
  #print(review)
  if review is not None and review != "nan":
    review = review.lower()
    review = re.sub('[^A-Za-z]+', ' ', review)

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(review)

    for w in word_tokens:
      if w in stop_words:
        review = review.replace(" " + w + " ", " ")
    all_bad_reviews_list_clean.append(review)

# %%
print(all_bad_reviews_list_clean[0])
# Out:
# too many students two local colleges go leave rubbish changing rooms sit like canteen going years cancel membership go gym group gym disgusting students hanging around machines messing around like school crowded ceo supports genocide civilians israel disgusting people

# %% [markdown]
# #### Use of BERTopic:

# %%
model = BERTopic(verbose=True)
model.fit(all_bad_reviews_list_clean)
topic, probabilities = model.transform(all_bad_reviews_list_clean)
# Out:
# 2024-11-29 17:27:12,753 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/122 [00:00<?, ?it/s]
# 2024-11-29 17:28:55,111 - BERTopic - Embedding - Completed ✓
# ...

# %% [markdown]
# ### 3. List out the top topics along with their document frequencies

# %%
model.get_topic_freq().head(10)
# Out:
#     Topic  Count
# 1      -1   1675
# 2       0    185
# 8       1    146
# 3       2    134
# 19      3    113
# 11      4    110
# 4       5    104
# 24      6     93
# 20      7     82
# 10      8     75

# %% [markdown]
# ###8. For 10 clusters, provide a brief description in the Notebook of the topics they comprise of along with the general theme of the cluster, evidenced by the top words within each cluster's topics.

# %%
model.get_topic(-1)
# Out:
# [('gym', 0.017914425733818587),
#  ('equipment', 0.01294043390802382),
#  ('staff', 0.01146816543294195),
#  ('one', 0.010676517330278622),
#  ('machines', 0.010666751520563516),
#  ('people', 0.010654149074799122),
#  ('like', 0.009070634291397935),
#  ('time', 0.008992741565009753),
#  ('puregym', 0.008983982908360172),
#  ('use', 0.008962926731427701)]

# %% [markdown]
# **Cluster -1:** The issue here seems to be people's use of machines and gym equipment which some members did not like.

# %%
model.get_topic(0)
# Out:
# [('air', 0.06982350002974003),
#  ('conditioning', 0.04207801946790915),
#  ('hot', 0.034840833946557626),
#  ('aircon', 0.03180372353855464),
#  ('con', 0.027663225647846977),
#  ('summer', 0.026151515171462306),
#  ('ac', 0.02481041182933603),
#  ('heat', 0.022923639512963428),
#  ('temperature', 0.02008209781829085),
#  ('working', 0.019675723828325192)]

# %% [markdown]
# **Cluster 0:** The theme of the topic is related to temperature settings of the gym in summer. It seems that the comment is suggesting that the gym management needs to keep a close checking on temperature setting during summer.

# %%
model.get_topic(1)
# Out:
# [('class', 0.08043306196279325),
#  ('classes', 0.06857033964560522),
#  ('booked', 0.026029940282924376),
#  ('instructors', 0.02419447287775572),
#  ('instructor', 0.023119268249241643),
#  ('cancelled', 0.02219983925335492),
#  ('spin', 0.018568088897620367),
#  ('time', 0.015302072502763848),
#  ('late', 0.012446558941679727),
#  ('good', 0.012296553748689647)]

# %% [markdown]
# **Cluster 1:** This topic is themed upon the isuue that instructors cancelled the booked classes quite late in time.

# %%
model.get_topic(2)
# Out:
# [('pass', 0.08367076415571045),
#  ('code', 0.0826246300928231),
#  ('pin', 0.07445365625896887),
#  ('day', 0.07081369993384966),
#  ('get', 0.030821192366185916),
#  ('bought', 0.028988911525747292),
#  ('access', 0.02847850189435552),
#  ('email', 0.02837562984607728),
#  ('paid', 0.02803150077078933),
#  ('help', 0.026390661487231848)]

# %% [markdown]
# **Cluster 2**: This issue seems to discuss the passcode for access was not emailed to them on the same day even without buying paid help.

# %%
model.get_topic(3)
# Out:
# [('parking', 0.15393942701590407),
#  ('car', 0.056540013685845006),
#  ('park', 0.043190097892993336),
#  ('fine', 0.03681397495604163),
#  ('free', 0.03408103947024271),
#  ('fines', 0.031025628676945378),
#  ('reg', 0.029707654781804423),
#  ('ticket', 0.022628674654430456),
#  ('website', 0.020873430895184293),
#  ('enter', 0.020714363756139244)]

# %% [markdown]
# **Cluster 3**: The issue seems to about car parking fines which the user had to pay by entering the ticket number and registration of the car on website.

# %%
model.get_topic(4)
# Out:
# [('toilets', 0.06438687763075342),
#  ('toilet', 0.048657717489526034),
#  ('changing', 0.030938583842080987),
#  ('dirty', 0.027531162221346796),
#  ('rooms', 0.024940478279362875),
#  ('always', 0.023996708810019123),
#  ('cleaning', 0.02108211727115677),
#  ('smell', 0.020134217065604497),
#  ('soap', 0.01968032843107972),
#  ('roll', 0.01785546767707341)]

# %% [markdown]
# **Cluster 4:** The issue is related to cleaning in the toilets of the gym, it was reported that changing rooms were dirty, toils were smelly and these needed soap and rolls regularly provided.

# %%
model.get_topic(5)
# Out:
# [('weights', 0.046264316445878535),
#  ('bench', 0.03647369632289986),
#  ('weight', 0.03270469126929705),
#  ('equipment', 0.028636782750725755),
#  ('plates', 0.027445061338144387),
#  ('benches', 0.026944378126705328),
#  ('dumbbells', 0.02635449424395284),
#  ('enough', 0.022409062501638495),
#  ('kg', 0.021185795743595963),
#  ('racks', 0.02076602300981862)]

# %% [markdown]
# **Cluster 5:** This issue seemed to be about the weights equipment such as dumbbells, plates and benches were not enough or racks needed to be upgraded.

# %%
model.get_topic(6)
# Out:
# [('music', 0.10888828107043852),
#  ('loud', 0.06471027975204309),
#  ('noise', 0.033105388459950494),
#  ('hear', 0.028601964687346413),
#  ('volume', 0.02561105237329543),
#  ('classes', 0.025406343516078567),
#  ('headphones', 0.024188216130334575),
#  ('class', 0.01956203674678453),
#  ('gym', 0.01794639840690059),
#  ('play', 0.016724901950779043)]

# %% [markdown]
# **Cluster 6:** This issue refers to the level of noise and volume of music in the gym. One had to use headphones in the gym.

# %%
model.get_topic(7)
# Out:
# [('closed', 0.11239315006423685),
#  ('open', 0.03782412028109491),
#  ('days', 0.03718433724992407),
#  ('christmas', 0.03667969178008038),
#  ('day', 0.028822118918401498),
#  ('gym', 0.02841950584710509),
#  ('opening', 0.027154203667385808),
#  ('email', 0.023071907270295483),
#  ('closing', 0.01976325915383056),
#  ('th', 0.019696652109817882)]

# %% [markdown]
# **Cluster 7:** There was no email about the opening/closing days by the gym during Chtistmas period.

# %%
model.get_topic(8)
# Out:
# [('manager', 0.030793680002510312),
#  ('rude', 0.03066444102603736),
#  ('member', 0.02190523633512697),
#  ('gym', 0.02059849246951974),
#  ('staff', 0.01837660228527414),
#  ('said', 0.017274670992155107),
#  ('attitude', 0.016476451869345807),
#  ('personal', 0.015306786025699782),
#  ('guy', 0.015023013010115308),
#  ('made', 0.013971700843804094)]

# %% [markdown]
# **Cluster 8:** This review mentioned that the member of staff was rude and made personal remarks. This was reported to the manager.

# %%
model.get_topic(9)
# Out:
# [('smell', 0.06695291869354676),
#  ('smells', 0.044408670361938574),
#  ('ventilation', 0.03502087535624316),
#  ('stinks', 0.029644936989001745),
#  ('gym', 0.026870045729995694),
#  ('air', 0.025618567300985683),
#  ('bad', 0.0242132272437755),
#  ('smelly', 0.02204399949647303),
#  ('this', 0.019382232863400014),
#  ('ever', 0.01754702289988443)]

# %% [markdown]
# **Cluster 9:** The issue here was about the air quality in the gym and the small in the gym needed ventilation as the smell aticks in that gym.

# %% [markdown]
# ### 5. Show an interactive visualisation of the topics to identify the cluster of topics and to understand the intertopic distance map

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 6. Show a barchart of the topics, displaying the top 5 words in each topic

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###7. Plot a heatmap, showcasing the similarity matrix

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Hierarchical clustering which shows a dendogram.

# %%
hierarchical_topics = model.hierarchical_topics(all_bad_reviews_list_clean)
model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 46/46 [00:00<00:00, 247.31it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Section: Perform Further Data Investigation
#
# ##1. List out the top 20 locations with the highest number of negative reviews. Do this separately for Google and Trustpilot's reviews, and comment on the result. Are the locations roughly similar in both data sets?
#
# ### 1a. Google Data Set

# %%
gNRdf_sortedby_reviews = gNRdf.sort_values(by='Overall Score', ascending=True)
gNRdf_sortedbyrev_top20 = gNRdf_sortedby_reviews.head(20)
# Get the top 20 Overall scores as a list
gNRdf_sorted20_Loc_List = gNRdf_sortedby_reviews.head(20)['Club\'s Name'].to_list()

# %%
gNRdf_sortedbyrev_top20
# Out:
#               SurveyID for external use (e.g. tech support)  \
# Customer Name
# **                                 e9b62vyxtkwrrrfyzc5hz6rk
# **                                   e8cw4ndx8xfnx67wc39pht
# **                                   ey8ntysx8xfnx67wc39pht
# **                                   ewtkpkbw8xfnx67wc39pht
# **                                   edbs88zw8xfnx67wc39pht
# **                                   e8pf993t8xfnx67wc39pht
# **                                   er5k993t8xfnx67wc39pht
# **                                   ecmykfxt8xfnx67wc39pht
# **                                   et6pdv7t8xfnx67wc39pht
# **                                   epbpvkdv8xfnx67wc39pht
# **                                   e5ck769s8xfnx67wc39pht
# **                                   evch62m38xfnx67wc39pht
# **                                   ebvzt8y38xfnx67wc39pht
# **                                   e6b8t8y38xfnx67wc39pht
# ...

# %% [markdown]
# ###1b. Trustpilot Data Set

# %%
tNRdf
# Out:
#                          Review Created (UTC)   Review Consumer User ID  \
# Review ID
# 663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 663cf54657cc0d5b9e4c3cf6  2024-05-09 18:09:00  663cf54563436600872ebfaf
# 663cb2bb3dd3bfa5d9aa722d  2024-05-09 13:25:00  663cb2bac225531f31f22a41
# 663cb0d7d2ae954c99ee3bb1  2024-05-09 13:17:00  663cb0d6cb6e8d68d6aacb9c
# 663ca6eef65e849c2d5d78d9  2024-05-09 12:35:00  601e9e42862682001b88eb67
# ...                                       ...                       ...
# 64650b23746ca7dfea1f2295  2023-05-17 19:13:00  637f6cfc06d9ed0012704ab7
# 64650222e9b78858b84cd8ea  2023-05-17 18:34:00  6465021a98dbf4001253f23f
# 6464f7df088d79de92813104  2023-05-17 17:50:00  6464f7bd8fef9f001256c5d2
# 6464e761c73e7c45f251dc0e  2023-05-17 16:40:00  60522cf2b9cf59001a351091
# 6464c9791c8f4e0876e86f30  2023-05-17 14:32:00  5d474c3817d44eefb5c373cf
#
#                                                                Review Title  \
# Review ID
# ...

# %%
tNRdf_sortedby_reviews = tNRdf.sort_values(by='Review Stars', ascending=True)
tNRdf_sortedbyrev_top20 = tNRdf_sortedby_reviews.head(20)
# Get the top 20 Overall scores as a list
tNRdf_sorted20_Loc_List = tNRdf_sortedby_reviews.head(20)['Location Name'].to_list()

# %%
tNRdf_sortedbyrev_top20
# Out:
#                          Review Created (UTC)   Review Consumer User ID  \
# Review ID
# 663d375859621080d08e6198  2024-05-09 22:51:00  57171ba90000ff000a18f905
# 6583399312103d5d8811b855  2023-12-20 20:59:00  58bd3d570000ff000a7e729f
# 6583396335889bb3c17fa20d  2023-12-20 20:58:00  59e0d7d10000ff000ad4a5f7
# 658338197fe1b55e46bc4f27  2023-12-20 20:53:00  658338174e183f00128cb69a
# 6583369370ee74e0e35f4a5a  2023-12-20 20:46:00  62a0c63a871da70014621d29
# 6583362e475558e967167082  2023-12-20 20:45:00  6009a66ef618e10019c389d1
# 65833528c16cffb84738efcb  2023-12-20 20:40:00  5d3593558c9ca1d9a6e9ef37
# 658333f10520b3faf8c666c1  2023-12-20 20:35:00  5bd98e7f4de5666d3483a7c3
# 658333d30b4230a318a0799a  2023-12-20 20:34:00  5f463ac56e8073153280d65a
# 65832ef3df19d074ff306a56  2023-12-20 20:14:00  5ee6dbe2d05e0acb8b7de129
# 65832ecfb4c8cdd1150d9d4b  2023-12-20 20:13:00  61c46221f7000700126d95bb
# 65832db5f9ee6f2fc97089fe  2023-12-20 20:08:00  65832db463d8420013473d50
# ...

# %% [markdown]
# ### Comment on the result. Are the locations roughly similar in both data sets?

# %% [markdown]
# ##2. Merge the 2 data sets using Location Name and Club's Name.
# ### Now, list out the following:
# ### • Locations
# ### • Number of Trustpilot reviews for this location
# ### • Number of Google reviews for this location
# ### • Total number of reviews for this location (sum of Google reviews and Trustpilot reviews)
#
# ###Sort based on the total number of reviews.
#
# What is not clear in the above instruction whether we need to merge the two dara sets with 20 rows of highest negative review or the whole data sets. So, we'll assume that the original two data sets are required to be merged.

# %%
gNRdf_sortedbyrev_top20_score_loc = gNRdf_sortedbyrev_top20[['Club\'s Name', 'Overall Score', 'Comment']]
tNRdf_sortedbyrev_top20_score_loc = tNRdf_sortedbyrev_top20[['Location Name', 'Review Stars', 'Review Content']]
Mergedtop20_gNRdf_tNRdf = pd.merge(gNRdf_sortedbyrev_top20_score_loc, tNRdf_sortedbyrev_top20_score_loc, left_on='Club\'s Name', right_on='Location Name')
# The above merged dataframe will not have same location name on the same row.

# %%
Mergedtop20_gNRdf_tNRdf
# Out:
#               Club's Name  Overall Score  \
# 0     Sutton Times Square              1
# 1  Reading Caversham Road              1
#
#                                              Comment           Location Name  \
# 0  Only giving 1 star as there is no option for z...     Sutton Times Square
# 1  Decent gym and have been a member for a while ...  Reading Caversham Road
#
#    Review Stars                          Review Content
# 0             1           Extremely busy, no fresh air.
# 1             1  Not clean,smelling, toilets are awful.

# %%
gNRdf_score_loc_rev = gNRdf[['Club\'s Name', 'Overall Score', 'Comment']]
tNRdf_score_loc_rev = tNRdf[['Location Name', 'Review Stars', 'Review Content']]
Merged_gNRdf_tNRdf = pd.merge(gNRdf_score_loc_rev, tNRdf_score_loc_rev, left_on='Club\'s Name', right_on='Location Name')

# %%
Merged_gNRdf_tNRdf
# Out:
#                   Club's Name  Overall Score  \
# 0      Cambridge Leisure Park              1
# 1      Cambridge Leisure Park              1
# 2      Cambridge Leisure Park              1
# 3      Cambridge Leisure Park              1
# 4          Bristol Union Gate              1
# ...                       ...            ...
# 16263     London Muswell Hill              1
# 16264     London Muswell Hill              1
# 16265     London Muswell Hill              1
# 16266     London Muswell Hill              1
# 16267     London Muswell Hill              1
#
#                                                  Comment  \
# 0      Too many students from two local colleges go h...
# 1      Too many students from two local colleges go h...
# 2      Too many students from two local colleges go h...
# 3      Too many students from two local colleges go h...
# 4      (current member)\n\nGym is quite dirty, more o...
# ...                                                  ...
# ...

# %%
# for every location, we find the number of Google reviews and Trustpilot reviews
Merged_gNRdf_tNRdf_sortedbyscore = Merged_gNRdf_tNRdf.sort_values(by='Overall Score', ascending=True)
Merged_gNRdf_tNRdf_sortedbyscore
# Out:
#                   Club's Name  Overall Score  \
# 0      Cambridge Leisure Park              1
# 9857                     York              1
# 9858                     York              1
# 9859                     York              1
# 9860                     York              1
# ...                       ...            ...
# 12238        London Stratford              2
# 12237        London Stratford              2
# 12236        London Stratford              2
# 12244        London Stratford              2
# 11447                   Epsom              2
#
#                                                  Comment  \
# 0      Too many students from two local colleges go h...
# 9857   Awful for hygiene. Get more cleaning stations ...
# 9858   Awful for hygiene. Get more cleaning stations ...
# 9859   Awful for hygiene. Get more cleaning stations ...
# 9860   Awful for hygiene. Get more cleaning stations ...
# ...                                                  ...
# ...

# %%
gsumdf = pd.DataFrame(Merged_gNRdf_tNRdf_sortedbyscore.groupby('Club\'s Name')['Overall Score'].count())
gsumdf
# Out:
#                         Overall Score
# Club's Name
# Aberdeen Kittybrewster             24
# Aberdeen Rubislaw                   3
# Aberdeen Shiprow                    8
# Aintree                            35
# Alloa                               8
# ...                               ...
# Wolverhampton South                28
# Worcester                          12
# Wrexham                           104
# Yate                               28
# York                               96
#
# [290 rows x 1 columns]

# %%
# for every location, we find the number of Google reviews and Trustpilot reviews
Merged_tNRdf_gNRdf_sortedbyscore = Merged_gNRdf_tNRdf.sort_values(by='Review Stars', ascending=True)
Merged_tNRdf_gNRdf_sortedbyscore
# Out:
#                   Club's Name  Overall Score  \
# 0      Cambridge Leisure Park              1
# 9813      Sutton Times Square              1
# 9814              London Oval              1
# 9817              London Oval              1
# 9818            West Thurrock              1
# ...                       ...            ...
# 12061        London Stratford              1
# 2834       Blackburn The Mall              2
# 5325     London Swiss Cottage              1
# 5330     London Swiss Cottage              1
# 11427                 Runcorn              1
#
#                                                  Comment  \
# 0      Too many students from two local colleges go h...
# 9813   HORRIBLE EXPERIENCE paid for nothing can’t acc...
# 9814   Tried this gym out, 1 of the worse gyms ive be...
# 9817   Tried this gym out, 1 of the worse gyms ive be...
# 9818   I give zero if I could . I have booked 1-2-1 s...
# ...                                                  ...
# ...

# %%
tsumdf = pd.DataFrame(Merged_tNRdf_gNRdf_sortedbyscore.groupby('Location Name')['Review Stars'].count())
tsumdf
# Out:
#                         Review Stars
# Location Name
# Aberdeen Kittybrewster            24
# Aberdeen Rubislaw                  3
# Aberdeen Shiprow                   8
# Aintree                           35
# Alloa                              8
# ...                              ...
# Wolverhampton South               28
# Worcester                         12
# Wrexham                          104
# Yate                              28
# York                              96
#
# [290 rows x 1 columns]

# %% [markdown]
# For every location, we now disply the location name, number of Google reviews, number of Trustpilot reviews  and total number of reviews in a dataframe.

# %%
totalsdf = pd.DataFrame(columns=['Location', 'Google Reviews', 'Trustpilot Reviews', 'Total Reviews'])
totalsdf['Location'] = tsumdf.index
totalsdf['Google Reviews'] = gsumdf['Overall Score'].to_numpy()
totalsdf['Trustpilot Reviews'] = tsumdf['Review Stars'].to_numpy()
totalsdf['Total Reviews'] = totalsdf['Google Reviews'] + totalsdf['Trustpilot Reviews']
totalsdf
# Out:
#                    Location  Google Reviews  Trustpilot Reviews  Total Reviews
# 0    Aberdeen Kittybrewster              24                  24             48
# 1         Aberdeen Rubislaw               3                   3              6
# 2          Aberdeen Shiprow               8                   8             16
# 3                   Aintree              35                  35             70
# 4                     Alloa               8                   8             16
# ..                      ...             ...                 ...            ...
# 285     Wolverhampton South              28                  28             56
# 286               Worcester              12                  12             24
# 287                 Wrexham             104                 104            208
# 288                    Yate              28                  28             56
# 289                    York              96                  96            192
#
# [290 rows x 4 columns]

# %%
sorted_totalsdf = totalsdf.sort_values(by='Total Reviews', ascending=False)

# %%
sorted_totalsdf.reset_index()
# Out:
#      index                 Location  Google Reviews  Trustpilot Reviews  \
# 0      176         London Stratford            1298                1298
# 1      145           London Enfield             575                 575
# 2      117  Leicester Walnut Street             550                 550
# 3      178     London Swiss Cottage             360                 360
# 4       22   Birmingham City Centre             294                 294
# ..     ...                      ...             ...                 ...
# 285      5               Altrincham               2                   2
# 286    253   Southend Fossetts Park               2                   2
# 287     10               Barnstaple               2                   2
# 288     61                  Consett               2                   2
# 289     90        Glasgow Milngavie               1                   1
#
#      Total Reviews
# 0             2596
# 1             1150
# 2             1100
# 3              720
# ...

# %% [markdown]
# ##3. For the top 30 locations, redo the word frequency and word cloud. Comment on the results, and highlight if the results are different from the first run.
#
# #### For this, we first build lists **gNRdocuments_top30Lst** and **tNRdocument_top30Lst** to hold all the reviews of top 30 locations from the **totalsdf** dataframe:

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import string

# %%
gNRdocuments_top30 = []
tNRdocuments_top30 = []

# Merge the two DataFrames on the relevant columns
merged_df = pd.merge(gNRdf, totalsdf, left_on='Club\'s Name', right_on='Location', how='inner')

# Now you can access the 'Comment' column based on the merged data
gNRdocuments_top30.append(merged_df['Comment'])

# Merge the two DataFrames on the relevant columns
merged_df = pd.merge(tNRdf, totalsdf, left_on='Location Name', right_on='Location', how='inner')

# Now you can access the 'Comment' column based on the merged data
tNRdocuments_top30.append(merged_df['Review Content'])

# %%
gNRdocuments_top30Lst = gNRdocuments_top30[0].to_list()
tNRdocuments_top30Lst = tNRdocuments_top30[0].to_list()
gNRdocuments_top30Lst
# Out:
# ['Too many students from two local colleges go her leave rubbish in changing rooms and sit there like there in a canteen. Been going here for 5 years will cancel my membership and go to gym group. This gym is disgusting students hanging around machines and messing around like there at school. Too over crowded.( And their ceo supports the genocide of civilians by Israel). Disgusting people!!',
#  "(current member)\n\nGym is quite dirty, more often than not there's no soap in the bathroom. There is zero airflow in the gym, it's like a sauna in here. Also the gym is often overcrowded anytime after 3pm.\n\nThe only good thing about this gym is the  location and the bring your buddy thing",
#  'This gym is way too hot to even workout in. There are no windows open and the AC barely works. The staff are no where near friendly they are always rude, especially the men. Just because you have clients doesn’t mean you don’t work here.',
# ...

# %%
tNRdocuments_top30
# Out:
# [0                           Extremely busy, no fresh air.
#  1       The men’s changing rooms smell bad. They need ...
#  2       No one was cleaning the equipment after use. C...
#  3       Not the best experience at 7am on a week day. ...
#  4       Staff have their hands tied but surely head of...
#                                ...
#  1836    There are lot of things to improve  There shou...
#  1837    Not enough weight plates for benches, spent ha...
#  1838    I've been a member of this gym for about  2 ye...
#  1839    Millhouses. Sheffield. Showers not warm enough...
#  1840    It’s an absolute joke, every week it’s either ...
#  Name: Review Content, Length: 1841, dtype: object]

# %%
def preprocess_text(text):

    num_freetxt = ''.join(word for word in text if not word.isdigit())
    # Tokenise the text.
    tokens = word_tokenize(num_freetxt.lower())

    numfree_tokens = [token for token in tokens if not token.isdigit()]

    # Remove punctuation.
    punc_free_tokens = [token for token in numfree_tokens if token not in string.punctuation]
    # Remove stopwords.
    filtered_tokens = [token for token in punc_free_tokens if token not in stopwords.words('english')]

    filtered_tokens = [token for token in filtered_tokens if len(token) > 1]

    # Lemmatise the tokens.
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    # Join the tokens back into a string.
    processed_text = ' '.join(lemmatized_tokens  )

    return processed_text

# %%
gNRdocsdf = pd.DataFrame(gNRdocuments_top30Lst, columns=['Comment']).reset_index()
tNRdocsdf = pd.DataFrame(tNRdocuments_top30Lst, columns=['Review Content']).reset_index()

# %%
gNRdocsdf
# Out:
#       index                                            Comment
# 0         0  Too many students from two local colleges go h...
# 1         1  (current member)\n\nGym is quite dirty, more o...
# 2         2  This gym is way too hot to even workout in. Th...
# 3         3  No access for wc 😢.  Empty and no assistance t...
# 4         4  After being at this gym for over a year I'm fi...
# ...     ...                                                ...
# 2042   2042  Equipment 7/10\n\nThey're pretty good, over th...
# 2043   2043  "Alright for the price. Some members are a bit...
# 2044   2044  Disorganised, cramped, and untidy. The old fre...
# 2045   2045  music always too loud, especially when cycling...
# 2046   2046  I used to love this gym, having been a member ...
#
# [2047 rows x 2 columns]

# %%
tNRdocsdf
# Out:
#       index                                     Review Content
# 0         0                      Extremely busy, no fresh air.
# 1         1  The men’s changing rooms smell bad. They need ...
# 2         2  No one was cleaning the equipment after use. C...
# 3         3  Not the best experience at 7am on a week day. ...
# 4         4  Staff have their hands tied but surely head of...
# ...     ...                                                ...
# 1836   1836  There are lot of things to improve  There shou...
# 1837   1837  Not enough weight plates for benches, spent ha...
# 1838   1838  I've been a member of this gym for about  2 ye...
# 1839   1839  Millhouses. Sheffield. Showers not warm enough...
# 1840   1840  It’s an absolute joke, every week it’s either ...
#
# [1841 rows x 2 columns]

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
gNRtokens30 = gNRdocsdf['Comment'].apply(preprocess_text)
tNRtokens30 = tNRdocsdf['Review Content'].apply(preprocess_text)
# Make a dataframe to add a column of 'cleantext' containing googletokens
gNRdocsdf['CleanText'] = gNRtokens30
tNRdocsdf['CleanText'] = tNRtokens30

# %%
gNRdocsdf
# Out:
#       index                                            Comment  \
# 0         0  Too many students from two local colleges go h...
# 1         1  (current member)\n\nGym is quite dirty, more o...
# 2         2  This gym is way too hot to even workout in. Th...
# 3         3  No access for wc 😢.  Empty and no assistance t...
# 4         4  After being at this gym for over a year I'm fi...
# ...     ...                                                ...
# 2042   2042  Equipment 7/10\n\nThey're pretty good, over th...
# 2043   2043  "Alright for the price. Some members are a bit...
# 2044   2044  Disorganised, cramped, and untidy. The old fre...
# 2045   2045  music always too loud, especially when cycling...
# 2046   2046  I used to love this gym, having been a member ...
#
#                                               CleanText
# 0     many student two local college go leave rubbis...
# 1     current member gym quite dirty often 's soap b...
# ...

# %%
tNRdocsdf
# Out:
#       index                                     Review Content  \
# 0         0                      Extremely busy, no fresh air.
# 1         1  The men’s changing rooms smell bad. They need ...
# 2         2  No one was cleaning the equipment after use. C...
# 3         3  Not the best experience at 7am on a week day. ...
# 4         4  Staff have their hands tied but surely head of...
# ...     ...                                                ...
# 1836   1836  There are lot of things to improve  There shou...
# 1837   1837  Not enough weight plates for benches, spent ha...
# 1838   1838  I've been a member of this gym for about  2 ye...
# 1839   1839  Millhouses. Sheffield. Showers not warm enough...
# 1840   1840  It’s an absolute joke, every week it’s either ...
#
#                                               CleanText
# 0                              extremely busy fresh air
# 1     men changing room smell bad need deep clean so...
# ...

# %% [markdown]
# ### 3a. Frequency distribution for Top 30 Locations Google Reviews

# %%
from nltk import FreqDist
from nltk.tokenize import RegexpTokenizer, word_tokenize
gNRdocs = gNRdocsdf['CleanText'].to_list()
# Tokenize the text into individual words
tokenizer = nltk.RegexpTokenizer(r"\w+")
gNRtokens30 = tokenizer.tokenize(str(gNRdocs))
gNRtokens30 = [token for token in gNRtokens30 if len(token) > 1]
# Now gcldocs contains all comments tokenized by NLTK word_tokenizer
# create a FreqDist object
gfreq_dist = FreqDist(gNRtokens30)

# total N
print('N:',gfreq_dist.N())

# Most frequent words
print("Most frequent words (top 30 locations):", gfreq_dist.most_common(10))

# Plot the 10 most frequent words
gfreq_dist.plot(10)
print()
# Out:
# N: 65907
# Most frequent words (top 30 locations): [('gym', 2724), ('equipment', 776), ('machine', 655), ('time', 609), ('staff', 596), ('people', 489), ('one', 479), ('get', 436), ('like', 378), ('member', 375)]

# %% [markdown]
# ### 3b. Frequency distribution for Top 30 Locations Trustpilot Reviews

# %%
from nltk import FreqDist
from nltk.tokenize import RegexpTokenizer, word_tokenize

tNRdocs = tNRdocsdf['CleanText'].to_list()
# Tokenize the text into individual words
tokenizer = nltk.RegexpTokenizer(r"\w+")
tNRtokens30 = tokenizer.tokenize(str(tNRdocs))
tNRtokens30 = [token for token in tNRtokens30 if len(token) > 1]
# Now gcldocs contains all comments tokenized by NLTK word_tokenizer
# create a FreqDist object
gfreq_dist = FreqDist(tNRtokens30)

# total N
print('N:',gfreq_dist.N())

# Most frequent words
print("Most frequent words:", gfreq_dist.most_common(10))

# Plot the 10 most frequent words
gfreq_dist.plot(10)
print()
# Out:
# N: 61072
# Most frequent words: [('gym', 2427), ('equipment', 561), ('machine', 515), ('time', 502), ('member', 457), ('one', 454), ('staff', 452), ('class', 441), ('get', 403), ('shower', 374)]

# %% [markdown]
# ### 3c. Google Reviews - Bar chart (Top 30 Locations)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Creating FreqDist for Top 30 Locations of negative reviews, keeping the 10 most common tokens
all_fdist = FreqDist(gNRtokens30).most_common(10)

## Conversion to Pandas series via Python Dictionary for easier plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,10))

## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
# Set a color palette
color_palette = sns.color_palette("husl", len(all_fdist))

# Create the barplot with the specified color palette
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, hue=all_fdist.index, ax=ax, palette=color_palette, legend=False)
plt.xticks(rotation=30, horizontalalignment='right')

# Remove the default legend
#ax.legend().remove()
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Words in Negative Reviews of Google Data Set - Top 30 Locations')

# Display the plot
plt.show()

# %% [markdown]
# ### 3d. Trustpilot Reviews - Bar Charts (Top 30 Locations)

# %%
## Creating FreqDist for Top 30 Locations, keeping the 10 most common tokens
all_fdist = FreqDist(tNRtokens30).most_common(10)

## Conversion to Pandas series via Python Dictionary for easier plotting
all_fdist = pd.Series(dict(all_fdist))

## Setting figure, ax into variables
fig, ax = plt.subplots(figsize=(10,10))

## Seaborn plotting using Pandas attributes + xtick rotation for ease of viewing
# Set a color palette
color_palette = sns.color_palette("husl", len(all_fdist))

# Create the barplot with the specified color palette
all_plot = sns.barplot(x=all_fdist.index, y=all_fdist.values, hue=all_fdist.index, ax=ax, palette=color_palette, legend=False)
plt.xticks(rotation=30, horizontalalignment='right')

# Remove the default legend
#ax.legend().remove()
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 10 Words in Negative Reviews of Trustpilot Data Set - Top 30 Locations')

# Display the plot
plt.show()

# %% [markdown]
# ### 3e. Word Cloud for Google Reviews (Top 30 Locations)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''
stopwords = set(STOPWORDS)

comment_words += " ".join(gNRtokens30)+" "
wordcloud = WordCloud(width = 1000, height = 1000,
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# ### 3f. Word Cloud for Trustpilot Reviews (Top 30 Locations)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''
stopwords = set(STOPWORDS)

comment_words += " ".join(tNRtokens30)+" "
wordcloud = WordCloud(width = 1000, height = 1000,
                      background_color ='white',
                      stopwords = stopwords,
                      min_font_size = 10).generate(comment_words)

# plot the WordCloud image
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %% [markdown]
# The frequency distribution, bar charts and Word Cloud show very similar words being used in the reviews of top 30 locations common in both Google and Trustpilot. The list of top words has been almost the same in top 30 locations which had negative reviews.

# %% [markdown]
# ##4. For the top 30 locations, combine the reviews from Google and Trustpilot and run them through BERTopic.
# ##Comment on the following:
#
# ##Are the results any different from the first run of BERTopic?
# ##If so, what has changed?
# ##Are there any additional insights compared to the first run?

# %%
Reviews_gNRdf_top30 = pd.DataFrame(gNRdocsdf['Comment'])
Reviews_gNRdf_top30
# Out:
#                                                 Comment
# 0     Too many students from two local colleges go h...
# 1     (current member)\n\nGym is quite dirty, more o...
# 2     This gym is way too hot to even workout in. Th...
# 3     No access for wc 😢.  Empty and no assistance t...
# 4     After being at this gym for over a year I'm fi...
# ...                                                 ...
# 2042  Equipment 7/10\n\nThey're pretty good, over th...
# 2043  "Alright for the price. Some members are a bit...
# 2044  Disorganised, cramped, and untidy. The old fre...
# 2045  music always too loud, especially when cycling...
# 2046  I used to love this gym, having been a member ...
#
# [2047 rows x 1 columns]

# %%
Reviews_tNRdf_top30 = pd.DataFrame(tNRdocsdf['Review Content'])
Reviews_tNRdf_top30
# Out:
#                                          Review Content
# 0                         Extremely busy, no fresh air.
# 1     The men’s changing rooms smell bad. They need ...
# 2     No one was cleaning the equipment after use. C...
# 3     Not the best experience at 7am on a week day. ...
# 4     Staff have their hands tied but surely head of...
# ...                                                 ...
# 1836  There are lot of things to improve  There shou...
# 1837  Not enough weight plates for benches, spent ha...
# 1838  I've been a member of this gym for about  2 ye...
# 1839  Millhouses. Sheffield. Showers not warm enough...
# 1840  It’s an absolute joke, every week it’s either ...
#
# [1841 rows x 1 columns]

# %%
Rev_gNRList = Reviews_gNRdf_top30['Comment'].to_list()
Rev_tNRList = Reviews_tNRdf_top30['Review Content'].to_list()
MergedRev_gtNRList_top30 = Rev_gNRList + Rev_tNRList
MergedRev_gtNRdf_top30 = pd.DataFrame(MergedRev_gtNRList_top30, columns=['Reviews'])

# %%
print(MergedRev_gtNRdf_top30.shape)
MergedRev_gtNRdf_top30.head()
# Out:
# (3888, 1)
#                                              Reviews
# 0  Too many students from two local colleges go h...
# 1  (current member)\n\nGym is quite dirty, more o...
# 2  This gym is way too hot to even workout in. Th...
# 3  No access for wc 😢.  Empty and no assistance t...
# 4  After being at this gym for over a year I'm fi...

# %%
# !pip install -U plotly==5.19.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 33.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from nltk.tokenize import RegexpTokenizer

import seaborn as sns
import re

# %%
def word_cloud_display(df, key):
  top_number_of_results = 100
  all_reviews = df[key].str.lower().str.cat(sep=' ')
  all_text = re.sub('[^A-Za-z]+', ' ', all_reviews)

  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(all_text)
  filtered_all_reviews = [w for w in word_tokens if not w in stop_words]
  filtered_all_reviews = []
  for w in word_tokens:
      if w not in stop_words:
          filtered_all_reviews.append(w)

  all_reviews_no_short_words = [word for word in filtered_all_reviews if len(word) > 2]
  all_reviews_no_numbers = [word for word in all_reviews_no_short_words if not word.isnumeric()]
  word_distribution = nltk.FreqDist(all_reviews_no_numbers)
  reviews_word_frequency_distribution_df = pd.DataFrame(word_distribution.most_common(top_number_of_results),
                    columns=['Word', 'Frequency'])

  plt.figure(figsize=(10,10))
  sns.set_style("whitegrid")
  ax = sns.barplot(x="Word",y="Frequency", data=reviews_word_frequency_distribution_df.head(7))

  plt.figure(figsize = (100,100))
  wc = WordCloud(background_color = 'black', max_words = 1000,  max_font_size = 50)
  wc.generate(' '.join(all_reviews_no_numbers))
  plt.imshow(wc)
  plt.axis('off')

# %%
from transformers import pipeline

# %%
# !pip install bertopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.6 MB/s eta 0:00:00
# ...

# %%
from bertopic import BERTopic

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
all_bad_reviews_list_clean = []
for review in MergedRev_gtNRList_top30:
  #print(review)
  if review is not None and review != "nan":
    review = review.lower()
    review = re.sub('[^A-Za-z]+', ' ', review)

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(review)

    for w in word_tokens:
      if w in stop_words:
        review = review.replace(" " + w + " ", " ")
    all_bad_reviews_list_clean.append(review)

print(all_bad_reviews_list_clean[0])
# Out:
# too many students two local colleges go leave rubbish changing rooms sit like canteen going years cancel membership go gym group gym disgusting students hanging around machines messing around like school crowded ceo supports genocide civilians israel disgusting people

# %%
model = BERTopic(verbose=True)
model.fit(all_bad_reviews_list_clean)
topic, probabilities = model.transform(all_bad_reviews_list_clean)
# Out:
# 2024-12-03 11:28:18,863 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/122 [00:00<?, ?it/s]
# 2024-12-03 11:30:00,184 - BERTopic - Embedding - Completed ✓
# ...

# %%
model.get_topic_freq().head(10)
# Out:
#     Topic  Count
# 1      -1   1683
# 2       0    192
# 3       1    128
# 9       2    119
# 17      3    113
# 4       4    105
# 10      5    103
# 26      6    103
# 23      7     91
# 21      8     90

# %%
model.get_topic(-1)
# Out:
# [('gym', 0.01716266580977782),
#  ('equipment', 0.012646294975028548),
#  ('staff', 0.011247108451906868),
#  ('machines', 0.010636237670116275),
#  ('one', 0.010304075454986595),
#  ('people', 0.0099970835230738),
#  ('get', 0.009552989884816978),
#  ('time', 0.009124198739092482),
#  ('use', 0.008900743155995445),
#  ('like', 0.00856985317748927)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
hierarchical_topics = model.hierarchical_topics(all_bad_reviews_list_clean)
model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 45/45 [00:00<00:00, 189.57it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# We see that nothing much has changed from the first run, where we had taken all of the bad reveiws into account including all locations. In this run, we had taken top 30 locations which has not made any huge changes to the results. This means that it was sufficient to analyse the first 30 locations in bad reveiws, which would provide a clear enough picture of the issues that came up under discussion in bad reviews.

# %% [markdown]
# # Section: Conducting emotion analysis
#
# ##1. Import the BERT model bhadresh-savani/bert-base-uncased-emotion from Hugging Face, and set up a pipeline for text classification.
#
# ##2. With the help of an example sentence, run the model and display the different emotion classifications that the model outputs.

# %%
from transformers import pipeline
classifier = pipeline("text-classification",model='bhadresh-savani/bert-base-uncased-emotion', return_all_scores=True)
prediction = classifier("The meal at that restaurant was not tasty.", )
print(prediction)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/935 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/285 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
predictiondf = pd.DataFrame(prediction[0])
mysorted_predictiondf=predictiondf.sort_values(by='score', ascending=False)
mysorted_predictiondf
# Out:
#       label     score
# 3     anger  0.622348
# 2      love  0.193182
# 1       joy  0.161824
# 5  surprise  0.016140
# 4      fear  0.003391
# 0   sadness  0.003115

# %%
print(mysorted_predictiondf['label'].iloc[0])
print(mysorted_predictiondf['score'].iloc[0])
# Out:
# anger
# 0.6223480105400085

# %% [markdown]
# ##3. Run this model on both data sets, and capture the top emotion for each review.
#
# ###3a. Google Data Set

# %%
ggl_datadf = googledatadf[['Comment', 'Overall Score']]
ggl_data_lst = ggl_datadf['Comment'].to_list()
print(len(ggl_data_lst))
print(ggl_datadf.shape)
# Out:
# 13898
# (13898, 2)

# %%
ggl_datadf.reset_index()
# Out:
#       Customer Name                                            Comment  \
# 0                **  Too many students from two local colleges go h...
# 1                **  Best range of equipment, cheaper than regular ...
# 2                **  Good gym when it’s not busy, tend to get too b...
# 3                **  (current member)\n\nGym is quite dirty, more o...
# 4                **  Kom og betalte for en prøvetime i centret. Fik...
# ...             ...                                                ...
# 13893            **  Great gym and instructors. Please make sure th...
# 13894            **  Chiara's class is great fun and she is a fab i...
# 13895            **                                        Perfect gym
# 13896            **                         Loved the pump class today
# 13897            **  Excellent gym with very friendly staff. All th...
#
#        Overall Score
# 0                  1
# 1                  5
# 2                  4
# 3                  1
# ...

# %%
# We run the model on every Google review in ggl_datadf and obtain the label and
# score of the leading emotion for every review.
ggl_emotion_lst = []
ggl_score_lst = []
ggl_top_emotion_score_df = ggl_datadf.copy()
ggl_top_emotion_score_df['Top Emotion'] = ''
ggl_top_emotion_score_df['Score'] = ''
sorted_predictiondf = pd.DataFrame()
for index, row in ggl_top_emotion_score_df.iterrows():
  #iloc = ggl_datadf.index[row]
  r = str(row['Comment'])
  if(len(str(r)) < 1000):
    prediction = classifier(r)
    predictiondf = pd.DataFrame(prediction[0])
    sorted_predictiondf = predictiondf.sort_values(by='score', ascending=False)
    ggl_emotion_lst.append(sorted_predictiondf['label'].iloc[0])
    ggl_score_lst.append(sorted_predictiondf['score'].iloc[0])
  else:
    ggl_emotion_lst.append('Too Long')
    ggl_score_lst.append(-1.0)
ggl_top_emotion_score_df['Top Emotion'] = ggl_emotion_lst
ggl_top_emotion_score_df['Score'] = ggl_score_lst
print(ggl_top_emotion_score_df.shape)
# Out:
# (13898, 4)

# %%
ggl_top_emotion_score_df.reset_index()
# Out:
#       Customer Name                                            Comment  \
# 0                **  Too many students from two local colleges go h...
# 1                **  Best range of equipment, cheaper than regular ...
# 2                **  Good gym when it’s not busy, tend to get too b...
# 3                **  (current member)\n\nGym is quite dirty, more o...
# 4                **  Kom og betalte for en prøvetime i centret. Fik...
# ...             ...                                                ...
# 13893            **  Great gym and instructors. Please make sure th...
# 13894            **  Chiara's class is great fun and she is a fab i...
# 13895            **                                        Perfect gym
# 13896            **                         Loved the pump class today
# 13897            **  Excellent gym with very friendly staff. All th...
#
#        Overall Score Top Emotion     Score
# 0                  1       anger  0.994873
# ...

# %% [markdown]
# #### Note that some reviews were too long in both data sets, and due to their length, our code for emotion analysis returns 'Too long' in the 'Top Emotion' column and a -1.0 in the 'Score' column. We remove those rows from the dataframe

# %%
#find which rows of ggl_top_emotion_score_df have 'Top Emotion' as 'anger'
ggl_top_anger_df = ggl_top_emotion_score_df[ggl_top_emotion_score_df['Top Emotion'] == 'anger']

# %%
#drop the row in ggl_top_emotion_score_df where 'Top Emotion' is equal to
# 'Too Long' or 'Score' = -1.0
ggl_top_emotion_score_df = ggl_top_emotion_score_df[ggl_top_emotion_score_df['Top Emotion'] != 'Too Long']

# %%
ggl_top_emotion_score_df
# Out:
#                                                          Comment  \
# Customer Name
# **             Too many students from two local colleges go h...
# **             Best range of equipment, cheaper than regular ...
# **             Good gym when it’s not busy, tend to get too b...
# **             (current member)\n\nGym is quite dirty, more o...
# **             Kom og betalte for en prøvetime i centret. Fik...
# ...                                                          ...
# **             Great gym and instructors. Please make sure th...
# **             Chiara's class is great fun and she is a fab i...
# **                                                   Perfect gym
# **                                    Loved the pump class today
# **             Excellent gym with very friendly staff. All th...
#
#                Overall Score Top Emotion     Score
# Customer Name
# **                         1       anger  0.994873
# **                         5         joy  0.998419
# ...

# %%
ggl_top_anger_df
# Out:
#                                                          Comment  \
# Customer Name
# **             Too many students from two local colleges go h...
# **             Kom og betalte for en prøvetime i centret. Fik...
# **             This gym is way too hot to even workout in. Th...
# **                                                   شوارع جميله
# **             Wielka strefa cardio, jest zdecydowanie wszyst...
# ...                                                          ...
# **             Still needs to turn the music down for classes...
# **             "Alright for the price. Some members are a bit...
# **             music always too loud, especially when cycling...
# **             Good value, with lots of classes to choose fro...
# **             I used to love this gym, having been a member ...
#
#                Overall Score Top Emotion     Score
# Customer Name
# **                         1       anger  0.994873
# **                         1       anger  0.638616
# ...

# %% [markdown]
# ###3b. Trustpilot Data Set

# %%
tpt_datadf = tdatadf[['Review Content', 'Review Stars']]
tpt_data_lst = tpt_datadf['Review Content'].to_list()
print(tpt_datadf.shape)
# Out:
# (16673, 2)

# %%
# We run the model on every Google review in ggl_datadf and obtain the label and
# score of the leading emotion for every review.
tpt_emotion_lst = []
tpt_score_lst = []
tpt_top_emotion_score_df = tpt_datadf.copy()
tpt_top_emotion_score_df['Top Emotion'] = ''
tpt_top_emotion_score_df['Score'] = ''
sorted_predictiondf = pd.DataFrame()
for index, row in tpt_top_emotion_score_df.iterrows():
  #iloc = ggl_datadf.index[row]
  r = str(row['Review Content'])
  if(len(str(r)) < 1000):
    prediction = classifier(r)
    predictiondf = pd.DataFrame(prediction[0])
    sorted_predictiondf = predictiondf.sort_values(by='score', ascending=False)
    tpt_emotion_lst.append(sorted_predictiondf['label'].iloc[0])
    tpt_score_lst.append(sorted_predictiondf['score'].iloc[0])
  else:
    tpt_emotion_lst.append('Too Long')
    tpt_score_lst.append(-1.0)
tpt_top_emotion_score_df['Top Emotion'] = tpt_emotion_lst
tpt_top_emotion_score_df['Score'] = tpt_score_lst
print(tpt_top_emotion_score_df.shape)
# Out:
# (16673, 4)

# %%
tpt_top_emotion_score_df.reset_index()
# Out:
#                       Review ID  \
# 0      663d40378de0a14c26c2f63c
# 1      663d3c101ccfcc36fb28eb8c
# 2      663d375859621080d08e6198
# 3      663d4fa1f25670a3339ccf6d
# 4      663d3251d8367b7b3c4ace64
# ...                         ...
# 16668  6463f601734f97e68fb3311b
# 16669  6463f343746ca7dfea1e8cd4
# 16670  6463f2c0734f97e68fb32f87
# 16671  6463f271734f97e68fb32f62
# 16672  6463f009734f97e68fb32e16
#
#                                           Review Content  Review Stars  \
# 0                                A very good environment             5
# 1      I love to be part of this gym. Superb value fo...             5
# 2                          Extremely busy, no fresh air.             1
# 3                             Great vibes, fantastic gym             5
# 4                 Clean, well managed, classes are good.             5
# ...                                                  ...           ...
# 16668  I enjoy the classes and the weights etc are ea...             4
# ...

# %%
tpt_top_emotion_score_df = tpt_top_emotion_score_df[tpt_top_emotion_score_df['Top Emotion'] != 'Too Long']

# %%
tpt_top_emotion_score_df
# Out:
#                                                              Review Content  \
# Review ID
# 663d40378de0a14c26c2f63c                            A very good environment
# 663d3c101ccfcc36fb28eb8c  I love to be part of this gym. Superb value fo...
# 663d375859621080d08e6198                      Extremely busy, no fresh air.
# 663d4fa1f25670a3339ccf6d                         Great vibes, fantastic gym
# 663d3251d8367b7b3c4ace64             Clean, well managed, classes are good.
# ...                                                                     ...
# 6463f601734f97e68fb3311b  I enjoy the classes and the weights etc are ea...
# 6463f343746ca7dfea1e8cd4  Happy and helpful staff, feel very comfortable...
# 6463f2c0734f97e68fb32f87  Showers never maintain the same temp. Not clea...
# 6463f271734f97e68fb32f62  Getting back to gym after be off for 3 months ...
# 6463f009734f97e68fb32e16  I feel that that this gym is a great place to ...
#
# ...

# %%
#find which rows of tpt_top_emotion_score_df have 'Top Emotion' as 'anger'
tpt_top_anger_df = tpt_top_emotion_score_df[tpt_top_emotion_score_df['Top Emotion'] == 'anger']

# %%
tpt_top_anger_df
# Out:
#                                                              Review Content  \
# Review ID
# 663d19993594d38b4934238b  Having bought the membership it asked me to lo...
# 663cdc2b3283b72a42bfb8dd  Spacious, not too busy Would like to see some ...
# 663c9a2a0a31bed37e2bc92f  Easy to join and great value for money.  Plent...
# 663c717f1b24812b967a6bfb    I payed twice and i still didnt get my day pass
# 663c6792b6ef1e805c29f831  Was a member in the past, and coming back to h...
# ...                                                                     ...
# 6465173a734f97e68fb3cf04  This is probably a bit unfair as the gym insta...
# 646516c6746ca7dfea1f2c16                            Add some more machines.
# 64650b23746ca7dfea1f2295  Not enough weight plates for benches, spent ha...
# 6464a0b570b116f76a8475fe  Very crowded. Limited to what I could go on. P...
# 64649adc746ca7dfea1ec5c3  Not a bad gym but not alot of machines just al...
#
# ...

# %% [markdown]
# #### This part has concluded that there are 2341 reviews in Google data set where 'anger' was the top emotion detected by the model. For the Trustpilot, this emotion topped in 2502 reviews.

# %% [markdown]
# ##4. Use a bar plot to show the top emotion distribution for all negative reviews in both data sets
#
# #### For this part, we'll use the dataframe ggl_top_emotion_score_df for Google reviews and tpt_top_emotion_score_df for Trustpilot and get their subsets for which their scores are less than 3.

# %%
ggl_bad_top_emotion_score_df = ggl_top_emotion_score_df[ggl_top_emotion_score_df['Overall Score'] < 3]

# %%
ggl_bad_top_emotion_score_df
# Out:
#                                                          Comment  \
# Customer Name
# **             Too many students from two local colleges go h...
# **             (current member)\n\nGym is quite dirty, more o...
# **             Kom og betalte for en prøvetime i centret. Fik...
# **             This gym is way too hot to even workout in. Th...
# **             No access for wc 😢.  Empty and no assistance t...
# ...                                                          ...
# **             Can be busy sometimes. Best time to training i...
# **             "Alright for the price. Some members are a bit...
# **             Disorganised, cramped, and untidy. The old fre...
# **             music always too loud, especially when cycling...
# **             I used to love this gym, having been a member ...
#
#                Overall Score Top Emotion     Score
# Customer Name
# **                         1       anger  0.994873
# **                         1     sadness  0.993274
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# First bar plot to show top emotion distribution for all negative reviews in Google data set.
plt.figure(figsize=(10,6))
sns.countplot(x='Top Emotion', data=ggl_bad_top_emotion_score_df)
plt.title('Top Emotion Distribution for Negative Reviews in Google Data Set')
plt.xlabel('Top Emotion')
plt.ylabel('Count')
plt.show()

# %%
tpt_bad_top_emotion_score_df = tpt_top_emotion_score_df[tpt_top_emotion_score_df['Review Stars'] < 3]

# %%
tpt_bad_top_emotion_score_df
# Out:
#                                                              Review Content  \
# Review ID
# 663d375859621080d08e6198                      Extremely busy, no fresh air.
# 663cf54657cc0d5b9e4c3cf6  The men’s changing rooms smell bad. They need ...
# 663cb2bb3dd3bfa5d9aa722d  All I wanted to do was set up another debit ca...
# 663cb0d7d2ae954c99ee3bb1  What ever you do don’t downgrade your membersh...
# 663ca6eef65e849c2d5d78d9  Poor parking, not enough kit, unhelpful traine...
# ...                                                                     ...
# 64651947746ca7dfea1f2e23  There are lot of things to improve  There shou...
# 64650b23746ca7dfea1f2295  Not enough weight plates for benches, spent ha...
# 64650222e9b78858b84cd8ea  I haven't been to PureGym yet, I'm writing thi...
# 6464e761c73e7c45f251dc0e  Millhouses. Sheffield. Showers not warm enough...
# 6464c9791c8f4e0876e86f30  It’s an absolute joke, every week it’s either ...
#
# ...

# %%
# Next bar plot to show top emotion distribution for all negative reviews in Trustpilot data set.
plt.figure(figsize=(10,6))
sns.countplot(x='Top Emotion', data=tpt_bad_top_emotion_score_df)
plt.title('Top Emotion Distribution for Negative Reviews in Truspilot Data Set')
plt.xlabel('Top Emotion')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### In both of these bar charts, we note that 'anger' has the been biggest emotion of all in negative reviews. What is remarkable is that 'joy' is the second highest in Trustpilot negative reviews and third for Google reviews. It seems to us that people, in their reviews, have like the gym but have also criticised some of its dislikable features and gave low score. In both Google and Trustpilot, we notice that 'joy' and 'love' have featured significantly (among the highes six emotions) within the negative reviews, which can be quite a remarkable thing.

# %% [markdown]
# ##5. Extract all the negative reviews (from both data sets) where anger is top emotion
#
# For this, we use the dataframes **ggl_bad_top_emotion_score_df** and **tpt_bad_top_emotion_score_df** to extract those subsets where anger is the top emotion. These two frames are already containing negative review, and it will be easy to extract the desired subsets from.

# %%
ggl_bad_top_anger_df = ggl_bad_top_emotion_score_df[ggl_bad_top_emotion_score_df['Top Emotion'] == 'anger']
tpt_bad_top_anger_df = tpt_bad_top_emotion_score_df[tpt_bad_top_emotion_score_df['Top Emotion'] == 'anger']

# %%
ggl_bad_top_anger_df.reset_index()
# Out:
#      Customer Name                                            Comment  \
# 0               **  Too many students from two local colleges go h...
# 1               **  Kom og betalte for en prøvetime i centret. Fik...
# 2               **  This gym is way too hot to even workout in. Th...
# 3               **  After being at this gym for over a year I'm fi...
# 4               **  The gym is huge but where is all the equipment...
# ...            ...                                                ...
# 1132            **  Eine sehr bemerkbare verschlechterung. Die ger...
# 1133            **                 Not enough machines in womens side
# 1134            **  "Alright for the price. Some members are a bit...
# 1135            **  music always too loud, especially when cycling...
# 1136            **  I used to love this gym, having been a member ...
#
#       Overall Score Top Emotion     Score
# 0                 1       anger  0.994873
# ...

# %%
tpt_bad_top_anger_df.reset_index()
# Out:
#                      Review ID  \
# 0     663c717f1b24812b967a6bfb
# 1     663c67278db0990f3063f147
# 2     663bd24e12a583682edc24df
# 3     663bcec7b4eec6f68fd9170f
# 4     663b036441cf3e471b74b74a
# ...                        ...
# 1527  6466667d98c6a4b2267fa7f7
# 1528  6465f92df77bb0838c87e18c
# 1529  6465f23d734f97e68fb4252a
# 1530  6465d96d734f97e68fb414dd
# 1531  64650b23746ca7dfea1f2295
#
#                                          Review Content  Review Stars  \
# 0       I payed twice and i still didnt get my day pass             1
# 1     Not the best experience at 7am on a week day. ...             1
# 2     Got raped in this location multiple time wait ...             1
# 3               i got sent the code but it doesn’t work             1
# 4     they blocked my access to the gym, now I have ...             1
# ...                                                 ...           ...
# 1527  Don’t recommend this gym . There is a PT Jelen...             1
# ...

# %%
ggl_bad_rev_top_anger_df = ggl_bad_top_anger_df.drop(columns=['Top Emotion', 'Overall Score', 'Score'])
tpt_bad_rev_top_anger_df = tpt_bad_top_anger_df.drop(columns=['Top Emotion', 'Review Stars', 'Score'])

# %%
ggl_bad_rev_top_anger_lst = ggl_bad_rev_top_anger_df['Comment'].to_list()
tpt_bad_rev_top_anger_lst = tpt_bad_rev_top_anger_df['Review Content'].to_list()
merged_bad_rev_top_anger_lst = ggl_bad_rev_top_anger_lst + tpt_bad_rev_top_anger_lst

# %% [markdown]
# ##6. Run BERTopic on the output of the previous step

# %%
# !pip install -U plotly==5.19.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 103.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from nltk.tokenize import RegexpTokenizer

# %%
import seaborn as sns
import re

# %%
def word_cloud_display(df, key):
  top_number_of_results = 100
  all_reviews = df[key].str.lower().str.cat(sep=' ')
  all_text = re.sub('[^A-Za-z]+', ' ', all_reviews)

  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(all_text)
  filtered_all_reviews = [w for w in word_tokens if not w in stop_words]
  filtered_all_reviews = []
  for w in word_tokens:
      if w not in stop_words:
          filtered_all_reviews.append(w)
  all_reviews_no_short_words = [word for word in filtered_all_reviews if len(word) > 2]
  all_reviews_no_numbers = [word for word in all_reviews_no_short_words if not word.isnumeric()]
  word_distribution = nltk.FreqDist(all_reviews_no_numbers)
  reviews_word_frequency_distribution_df = pd.DataFrame(word_distribution.most_common(top_number_of_results),
                    columns=['Word', 'Frequency'])

  plt.figure(figsize=(10,10))
  sns.set_style("whitegrid")
  ax = sns.barplot(x="Word",y="Frequency", data=reviews_word_frequency_distribution_df.head(7))

  plt.figure(figsize = (100,100))
  wc = WordCloud(background_color = 'black', max_words = 1000,  max_font_size = 50)
  wc.generate(' '.join(all_reviews_no_numbers))
  plt.imshow(wc)
  plt.axis('off')

# %%
from transformers import pipeline

# %%
# !pip install bertopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.7 MB/s eta 0:00:00
# ...

# %%
from bertopic import BERTopic

nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
all_bad_reviews_top_anger_list_clean = []
for review in merged_bad_rev_top_anger_lst:
  #print(review)
  if review is not None and review != "nan":
    review = review.lower()
    review = re.sub('[^A-Za-z]+', ' ', review)

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(review)

    for w in word_tokens:
      if w in stop_words:
        review = review.replace(" " + w + " ", " ")
    all_bad_reviews_top_anger_list_clean.append(review)

# %%
print(all_bad_reviews_top_anger_list_clean[0])
# Out:
# too many students two local colleges go leave rubbish changing rooms sit like canteen going years cancel membership go gym group gym disgusting students hanging around machines messing around like school crowded ceo supports genocide civilians israel disgusting people

# %%
model = BERTopic(verbose=True)
model.fit(all_bad_reviews_top_anger_list_clean)
topic, probabilities = model.transform(all_bad_reviews_top_anger_list_clean)
# Out:
# 2024-12-11 21:03:36,914 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/84 [00:00<?, ?it/s]
# 2024-12-11 21:03:42,716 - BERTopic - Embedding - Completed ✓
# ...

# %%
model.get_topic_freq().head(10)
# Out:
#     Topic  Count
# 0      -1    951
# 1       0    205
# 26      1    147
# 4       2     88
# 31      3     80
# 20      4     78
# 7       5     77
# 6       6     62
# 21      7     61
# 11      8     55

# %%
model.get_topic(-1)
# Out:
# [('gym', 0.019110131221635136),
#  ('equipment', 0.013036565406238178),
#  ('people', 0.01193227844407987),
#  ('staff', 0.010867866702564928),
#  ('get', 0.010864559453554537),
#  ('one', 0.010658665018187246),
#  ('time', 0.010265160668712827),
#  ('machines', 0.00974656118533556),
#  ('membership', 0.00960374838708883),
#  ('weights', 0.009283705835976805)]

# %%
model.get_topic(0)
# Out:
# [('er', 0.05374966861159677),
#  ('og', 0.05036493996658834),
#  ('der', 0.04710048929362509),
#  ('ikke', 0.03947833235898082),
#  ('det', 0.03647374507954503),
#  ('und', 0.034907521964642044),
#  ('de', 0.03476092129142157),
#  ('die', 0.03167553923679589),
#  ('nicht', 0.0309505853713012),
#  ('man', 0.03060896662154666)]

# %%
model.get_topic(1)
# Out:
# [('pass', 0.08801303889632932),
#  ('day', 0.07562635267753413),
#  ('pin', 0.06972269598608472),
#  ('code', 0.05925950881471227),
#  ('bought', 0.033769824099887186),
#  ('get', 0.03344326832387712),
#  ('paid', 0.031800497773477286),
#  ('work', 0.025730102967597805),
#  ('email', 0.02475253418562334),
#  ('gym', 0.022726389420250813)]

# %%
model.get_topic(2)
# Out:
# [('rude', 0.038150386149615745),
#  ('staff', 0.027497895113523674),
#  ('manager', 0.024402109472495843),
#  ('member', 0.021586362420046613),
#  ('aggressive', 0.02103149737130302),
#  ('gym', 0.02082418607801734),
#  ('personal', 0.018958738137685588),
#  ('attitude', 0.016670173166861334),
#  ('pure', 0.015597800281770727),
#  ('guy', 0.01528099206962289)]

# %%
model.get_topic(3)
# Out:
# [('fee', 0.12896814700790873),
#  ('joining', 0.1222779533059843),
#  ('code', 0.07983850102948276),
#  ('promo', 0.06207943483308143),
#  ('discount', 0.061353979152670685),
#  ('charged', 0.052578080104586075),
#  ('applied', 0.035595970811222365),
#  ('membership', 0.03429683756380955),
#  ('month', 0.030297368493562255),
#  ('paid', 0.02975835111239676)]

# %%
model.get_topic(4)
# Out:
# [('membership', 0.06300110400726126),
#  ('cancel', 0.05538302186002685),
#  ('account', 0.049080105452138194),
#  ('month', 0.041802588882986325),
#  ('payment', 0.03557458401370211),
#  ('suspended', 0.03267656769720603),
#  ('cancellation', 0.03249592626085997),
#  ('cancelled', 0.030520591121931277),
#  ('email', 0.02964242497374375),
#  ('money', 0.02931329109583959)]

# %%
model.get_topic(5)
# Out:
# [('class', 0.09952110718533033),
#  ('classes', 0.09110449280240067),
#  ('booked', 0.04934060058379465),
#  ('cancelled', 0.04022684411370313),
#  ('book', 0.029660296748511276),
#  ('instructor', 0.026209308856789054),
#  ('instructors', 0.024845516594376768),
#  ('one', 0.01817782825100441),
#  ('min', 0.015948806615471132),
#  ('attend', 0.015817499834182392)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
hierarchical_topics = model.hierarchical_topics(all_bad_reviews_top_anger_list_clean)
model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 42/42 [00:00<00:00, 281.32it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Section: Using a large language model from Hugging Face

# %% [markdown]
# ## 1. We start working with Phi-3.5-mini-instruct and set the pipeline for text generation and a max length of 1,000 for each review.

# %%
import json

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
torch.random.manual_seed(0)

# %%
import pandas as pd
import numpy as np

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF']="expandable_segments:True"

# %%
# !pip install -U nvidia-cudnn-cu12 --index-url https://developer.download.nvidia.com/compute/redist/  # installs nvidia-cudnn
# Out:
# Looking in indexes: https://developer.download.nvidia.com/compute/redist/
# ...

# %%
# !nvidia-smi
# Out:
# Tue Dec 10 18:40:36 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0              45W / 400W |      5MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %%
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3.5-mini-instruct",
    device_map="cpu" if not torch.cuda.is_available() else "cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3.5-mini-instruct")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/3.45k [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3.5-mini-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)

# %%
generation_args = {
    "max_new_tokens": 500,
    "return_full_text": False,
    "temperature": 0.0,
    "do_sample": False,
}

# %%
messages_1 = [
    {"role": "system", "content": "You work as a data analyst insights guru for a large gym company and you want to find topics for improvments from customer reviews. You should return these in an array of strings only ['topic 1', 'topic 2', 'topic 3', ...]"},
    {"role": "user", "content": "In the following customer review interaction pick out a maximum of 5 main topics and return them as an array of topics: The showers are disgusting"},
    {"role": "assistant", "content": "['Shower cleanliness', 'odour', 'customer discomfort']"},
    {"role": "user", "content": "In the following customer review interaction pick out the main 5 topics and return them as an array of topics: I have paid my membership but I can't access the gym, I am still waiting on a code"},
]

# %%
output = pipe(messages_1, **generation_args)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# WARNING:transformers_modules.microsoft.Phi-3.5-mini-instruct.af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.

# %%
topic_list_string = output[0]['generated_text'].replace("'", '"')
print(topic_list_string)
# Out:
#  ["Membership access issues", "Delayed code provision", "Customer service response", "Payment processing", "Gym accessibility"]

# %%
topic_list = json.loads(topic_list_string)
print(topic_list)
# Out:
# ['Membership access issues', 'Delayed code provision', 'Customer service response', 'Payment processing', 'Gym accessibility']

# %%
bad_ggl_reviews_df = gdatadf[gdatadf['Overall Score'] < 3]
bad_ggl_reviews_df.isnull().sum()
# Out:
# SurveyID for external use (e.g. tech support)      0
# Club's Name                                        0
# Social Media Source                                0
# Creation Date                                      0
# Comment                                          433
# Overall Score                                      0
# dtype: int64

# %%
bad_ggl_reviews_df = bad_ggl_reviews_df.dropna(subset=['Comment'])

# %%
bad_ggl_reviews_df.isnull().sum()
# Out:
# SurveyID for external use (e.g. tech support)    0
# Club's Name                                      0
# Social Media Source                              0
# Creation Date                                    0
# Comment                                          0
# Overall Score                                    0
# dtype: int64

# %%
bad_ggl_reviews_df.reset_index()
# Out:
#      Customer Name SurveyID for external use (e.g. tech support)  \
# 0               **                      e9b62vyxtkwrrrfyzc5hz6rk
# 1               **                      edkrxvyxtkwrrrfyzc5hz6rk
# 2               **                      ewbyf88stkwrrrfyzc5hz6rk
# 3               **                      erx6f88stkwrrrfyzc5hz6rk
# 4               **                      em5fxz3stkwrrrfyzc5hz6rk
# ...            ...                                           ...
# 2780            **                          emm2t9tn9k6zn6mt9mb9
# 2781            **                          e3nr79tn9k6zn6mt9mb9
# 2782            **                          enkwn9tn9k6zn6mt9mb9
# 2783            **                          ebwbsbvn9k6zn6mt9mb9
# 2784            **                          e5hbbnvn9k6zn6mt9mb9
#
#                        Club's Name Social Media Source       Creation Date  \
# 0           Cambridge Leisure Park      Google Reviews 2024-05-09 22:48:39
# ...

# %%
bad_tpt_reviews_df = tdatadf[tdatadf['Review Stars'] < 3]
bad_tpt_reviews_df.isnull().sum()
# Out:
# Review Created (UTC)           0
# Review Consumer User ID        0
# Review Title                   0
# Review Content                 0
# Review Stars                   0
# Source Of Review               0
# Review Language                0
# Domain URL                     0
# Webshop Name                   0
# Business Unit ID               0
# Tags                        3543
# Company Reply Date (UTC)     129
# Location Name               1292
# Location ID                 1292
# dtype: int64

# %%
bad_ggl_reviews_list = bad_ggl_reviews_df["Comment"].to_list()
bad_tpt_reviews_list = bad_tpt_reviews_df["Review Content"].to_list()

bad_reviews_list = bad_ggl_reviews_list + bad_tpt_reviews_list

# %%
len(bad_reviews_list)
# Out:
# 6328

# %%
topics_llm = []
print(len(bad_reviews_list))
for review in bad_reviews_list[0:1000]:
  if len(str(review)) < 1000:
    messages_2 = [
      {"role": "user", "content": f"In the following customer review, pick out the main 3 topics. Return them in a numbered list format, with each one on a new line: {review}"},
    ]
    output = pipe(messages_2, **generation_args)

    #print(sequences[0]['generated_text'])
    #topic_list_string = output[0]['generated_text'].replace("'", '"')
    topic_list_string = output[0]['generated_text']
    #topic_list = json.loads(topic_list_string)
    # Split the string into lines

    topic_list = topic_list_string.strip().split('\n')

    # Clean up each line
    #topic_list = [line.split('. ', 1)[1].strip() for line in topic_list if line]
    topic_list = [line.split('. ', 1)[1].strip() if '. ' in line else line.strip() for line in topic_list if line]

    topics_llm.append(topic_list)

#np_topics_llm = np.array(topics_llm)
#np.save('np_topics_phi500.npy', np_topics_llm)
# Out:
# 6328
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# WARNING:transformers_modules.microsoft.Phi-3.5-mini-instruct.af0dfb8029e8a74545d0736d30cb6b58d2f0f3f0.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
loaded_arr = np.load('np_topics_phi500.npy')
loaded_topics_llm = loaded_arr.tolist()

# %%
len(topics_llm)
# Out:
# 950

# %%
topic_string_array = [item for row in topics_llm for item in row]
print(topic_string_array)
# Out:
# ['Uncleanliness and littering in changing rooms', 'Overcrowding and disruptive behavior of students', "Discontentment with management and controversial CEO's stance on a sensitive issue", 'Cleanliness and hygiene issues', 'Poor ventilation and overcrowding', 'Positive aspects: location and buddy system policy', 'Mangel på personlig instruktion og assistance', 'Risiko for uhensigtsmæssige skader', 'Selvstændige kropsviden og risiko for uansvarlighed', 'Uncomfortable temperature and inadequate air conditioning', 'Unfriendly and rude staff', 'Lack of staff engagement with clients', 'Lack of access to washroom facilities', 'Absence of assistance or customer service', 'Issue with forgotten pin and lack of guidance for access enablement', 'Overcrowding at the gym', 'Closure of St James PureGym', 'Lack of air conditioning and discomfort due to heat', 'Lack of gym equipment', 'Gym atmosphere and user experience', 'Potential for improvement in gym facilities', 'Air-conditioning malfunction', 
# ...

# %%
import numpy as np

# %%
transpose_topic_string_array = np.transpose(topic_string_array)
print(transpose_topic_string_array)
# Out:
# ['Uncleanliness and littering in changing rooms'
#  'Overcrowding and disruptive behavior of students'
#  "Discontentment with management and controversial CEO's stance on a sensitive issue"
#  ... 'Pay for gym membership' 'Parking facilities at gym'
#  'Fines for parking at gym']

# %% [markdown]
# ## 3. Run BERTopic on topic_string_array

# %%
from transformers import pipeline

# %%
# !pip install bertopic
from bertopic import BERTopic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')

from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS
from collections import Counter
from nltk.tokenize import RegexpTokenizer

import seaborn as sns
import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
topic_string_array_clean = []
for review in topic_string_array:
  #print(review)
  if review is not None and review != "nan":
    review = review.lower()
    review = re.sub('[^A-Za-z]+', ' ', review)

    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(review)

    for w in word_tokens:
      if w in stop_words:
        review = review.replace(" " + w + " ", " ")
    topic_string_array_clean.append(review)

# %%
model = BERTopic(verbose=True)
model.fit(topic_string_array_clean)
topic, probabilities = model.transform(topic_string_array_clean)
# Out:
# 2024-12-10 20:19:05,775 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/92 [00:00<?, ?it/s]
# 2024-12-10 20:19:09,960 - BERTopic - Embedding - Completed ✓
# ...

# %%
model.get_topic_freq().head(10)
# Out:
#     Topic  Count
# 7      -1    667
# 6       0    183
# 63      1     64
# 16      2     63
# 41      3     49
# 14      4     49
# 17      5     48
# 23      6     48
# 21      7     47
# 13      8     46

# %%
model.get_topic(-1)
# Out:
# [('lack', 0.012437525146460704),
#  ('gym', 0.012037825340446642),
#  ('machines', 0.010682663152857562),
#  ('staff', 0.010477302072427636),
#  ('layout', 0.009937134232086023),
#  ('equipment', 0.009690702581365885),
#  ('facilities', 0.009221873098261904),
#  ('space', 0.009142670208316208),
#  ('due', 0.008660681786916678),
#  ('inappropriate', 0.008652200135570828)]

# %%
model.get_topic(0)
# Out:
# [('og', 0.05243156937161268),
#  ('und', 0.04783688248641271),
#  ('af', 0.04139059734404552),
#  ('maskiner', 0.04139059734404552),
#  ('de', 0.03861249470709757),
#  ('der', 0.0320101372575345),
#  ('mangel', 0.02974121590788965),
#  ('von', 0.02643663636256858),
#  ('tr', 0.02505448745000111),
#  ('med', 0.02505448745000111)]

# %%
model.get_topic(1)
# Out:
# [('parking', 0.2543866868844192),
#  ('car', 0.066015623560552),
#  ('ticket', 0.055948785307183724),
#  ('fines', 0.04571882745359587),
#  ('voucher', 0.0451933980772911),
#  ('regulations', 0.03947111729293271),
#  ('charges', 0.03744938549449979),
#  ('penalties', 0.03318569609414813),
#  ('penalty', 0.03318569609414813),
#  ('validation', 0.03318569609414813)]

# %%
model.get_topic(2)
# Out:
# [('dissatisfaction', 0.2512084625906726),
#  ('customer', 0.0939591882760319),
#  ('preference', 0.06150831940921919),
#  ('disappointment', 0.05533008437497098),
#  ('complaint', 0.041497563281228236),
#  ('experience', 0.0377894888558722),
#  ('change', 0.03540192994314584),
#  ('establishment', 0.02766504218748549),
#  ('accusation', 0.02586226720007693),
#  ('unhappy', 0.02586226720007693)]

# %% [markdown]
# ## We notice that the topic that is related to staff behaviour has topped the list of topics from the limited set of 1000 reviews as input to our LLM. This is also evident by the barcharts in the Topic Word Scores below. The Intertopic Distance Map has also shown the variation that is also limited due a subset of the reviews used for the LLM. Hierarchical Clustering map also shows this variation.

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
hierarchical_topics = model.hierarchical_topics(topic_string_array_clean)
model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
# Out:
# 100%|██████████| 83/83 [00:00<00:00, 293.08it/s]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##4. Get Actionable Insights from topic_string_array and List them

# %% [markdown]
# ## Checking RAM for Runtime at this stage:

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
messages_3 = [
    {"role": "user", "content": f"For the following text topics obtained from negative customer reviews, can you give some actionable insights that would help this gym company?: {topic_string_array}"},
]

# %%
output = pipe(messages_3, **generation_args)
insights = output[0]['generated_text']
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-31-92617a702ce1> in <cell line: 1>()
# ----> 1 output = pipe(messages_3, **generation_args)
#       2 insights = output[0]['generated_text']
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     265             # We have one or more prompts in list-of-dicts format, so this is chat mode
#     266             if isinstance(text_inputs[0], dict):
# --> 267                 return super().__call__(Chat(text_inputs), **kwargs)
#     268             else:
#     269                 chats = [Chat(chat) for chat in text_inputs]  # 🐈 🐈 🐈
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1300             )
#    1301         else:
# ...

# %% [markdown]
# Due to the above memory error, we apply a batch size and display the actionable insights batch-wise:

# %%
# Instead of processing the entire topic_string_array:
    # output = pipe(messages_3, **generation_args)

    # Process in smaller batches:
batch_size = 30  # Adjust as needed
for i in range(0, len(topic_string_array), batch_size):
  batch = topic_string_array[i : i + batch_size]
  messages_3 = [
      {
          "role": "user",
          "content": f"For the following text topics obtained from negative customer reviews, can you give some actionable insights that would help this gym company?: {batch}",
      },
      ]
  output = pipe(messages_3, **generation_args)
  insights = output[0]['generated_text']
  print(insights)
  # Process insights for the current batch
# Out:
#  Based on the negative customer reviews, here are some actionable insights for the gym company to address the issues and improve their service:
#
# 1. **Cleanliness and Hygiene**: Implement a strict cleaning schedule for all areas, especially changing rooms. Provide hand sanitizers and disinfectant wipes throughout the gym. Address the issue of strong body odor by ensuring proper ventilation and encouraging members to shower before and after workouts.
#
# 2. **Overcrowding and Ventilation**: Consider expanding the gym space or optimizing the current layout to accommodate more members comfortably. Install a more efficient air conditioning system to maintain a comfortable temperature and improve air quality.
#
# 3. **Staff Training and Engagement**: Invest in staff training to improve customer service skills, etiquette, and knowledge of gym equipment. Encourage staff to engage with clients, answer questions, and provide assistance when needed.
#
# ...

# %%
print(len(topic_string_array))
# Out:
# 1449

# %% [markdown]
# #Section: Using Gensim
#
# ## 1. Perform the preprocessing required to run the LDA model from Gensim. Use the list of negative reviews (combined Google and Trustpilot reviews).

# %%
print(len(bad_reviews_list))
# Out:
# 6328

# %%
# !pip install gensim nltk datasets pyLDAvis ipykernel
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
documents = bad_reviews_list

# %%
documents[0]
# Out:
# 'Too many students from two local colleges go her leave rubbish in changing rooms and sit there like there in a canteen. Been going here for 5 years will cancel my membership and go to gym group. This gym is disgusting students hanging around machines and messing around like there at school. Too over crowded.( And their ceo supports the genocide of civilians by Israel). Disgusting people!!'

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string

# Download necessary NLTK data.
nltk.download('stopwords')
nltk.download('wordnet')

# Define stop words and punctuation.
stop = set(stopwords.words('english'))
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

# Function to clean the document.
def clean(doc):
    # Remove stop words and convert to lowercase.
    stop_free = " ".join([word for word in doc.lower().split() if word not in stop])
    # Remove punctuation.
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    # Lemmatise the text.
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
documents = [clean(doc) for doc in  documents]

# %%
# Tokenise the documents.
tokenized_docs = [doc.lower().split() for doc in documents]

# %% [markdown]
# ## Create dictionary and corpus
# Now, convert your preprocessed documents into a dictionary and corpus using Gensim.

# %%
# Create a dictionary representation of the documents.
from gensim import corpora
dictionary = corpora.Dictionary(tokenized_docs)


# Filter out words that occur fewer than 2 documents or more than 50% of the documents.
dictionary.filter_extremes(no_below=2, no_above=0.5)

# %% [markdown]
# ## Build the LDA model using the dictionary and corpus
#
# Adjust `num_topics` according to how many topics you want to model, and passes for the number of iterations over the corpus.

# %%
# Create a BOW representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

# Set parameters.
num_topics = 10
passes = 20

# %%
# Create the LDA model.
from gensim.models.ldamodel import LdaModel
lda_model = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, passes=passes)

# %% [markdown]
# ## View topics

# %%
# Print the topics.
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic))
# Out:
# Topic: 0
# Words: 0.028*"und" + 0.026*"die" + 0.020*"da" + 0.019*"ich" + 0.018*"nicht" + 0.016*"der" + 0.015*"ist" + 0.015*"e" + 0.012*"zu" + 0.009*"man"
# Topic: 1
# Words: 0.017*"shower" + 0.013*"water" + 0.012*"broken" + 0.012*"machine" + 0.011*"time" + 0.011*"month" + 0.010*"year" + 0.010*"changing" + 0.009*"week" + 0.008*"one"
# Topic: 2
# Words: 0.049*"class" + 0.017*"time" + 0.013*"one" + 0.012*"membership" + 0.011*"hour" + 0.009*"closed" + 0.009*"instructor" + 0.008*"open" + 0.008*"work" + 0.008*"staff"
# Topic: 3
# Words: 0.048*"member" + 0.026*"staff" + 0.018*"puregym" + 0.013*"manager" + 0.012*"management" + 0.012*"issue" + 0.009*"pure" + 0.008*"trainer" + 0.007*"personal" + 0.007*"experience"
# Topic: 4
# Words: 0.031*"equipment" + 0.029*"machine" + 0.019*"people" + 0.016*"weight" + 0.012*"one" + 0.012*"time" + 0.009*"go" + 0.009*"busy" + 0.009*"get" + 0.008*"enough"
# Topic: 5
# ...

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

# Prepare the visualisation.
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el6321323233306310241174768668" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# The above visualisation is an excellent means to view the frequency of relevant words in the selcted topic. The topic 1 in LDA is different from what LLM generated, and that's perhaps because we used a subset of all reviews for the LLM. In Gensim LDA, we have use all the reviews of both Google and Trustpilot.
